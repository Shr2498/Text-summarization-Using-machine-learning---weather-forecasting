# %%
import pandas as pd

df = pd.read_csv("weather_data_1hr.csv")

# %%
df
# Out:
#       loc_id        date  time isdaytime  tempC  tempF  windspeedMiles  \
# 0          1  2019-06-01     0        no     16     61               6
# 1          1  2019-06-01   100        no     16     60               6
# 2          1  2019-06-01   200        no     15     59               5
# 3          1  2019-06-01   300        no     15     58               5
# 4          1  2019-06-01   400        no     15     59               4
# ...      ...         ...   ...       ...    ...    ...             ...
# 1459       1  2019-07-31  1900        no     20     68              11
# 1460       1  2019-07-31  2000        no     20     67              11
# 1461       1  2019-07-31  2100        no     19     66              10
# 1462       1  2019-07-31  2200        no     18     65               9
# 1463       1  2019-07-31  2300        no     18     64               8
#
#       windspeedKmph  winddirdegree winddir16point  ...  HeatIndexC HeatIndexF  \
# 0                10            228             SW  ...          16         61
# 1                 9            230             SW  ...          16         60
# 2                 9            233             SW  ...          15         59
# 3                 8            235             SW  ...          15         58
# 4                 7            229             SW  ...          15         59
# ...             ...            ...            ...  ...         ...        ...
# 1459             18            260              W  ...          20         68
# 1460             17            258            WSW  ...          20         67
# 1461             15            257            WSW  ...          19         66
# 1462             15            258            WSW  ...          18         65
# 1463             14            259            WSW  ...          18         64
#
#      DewPointC  DewPointF  WindChillC  WindChillF  WindGustMiles  \
# 0           12         54          16          61              7
# 1           12         53          16          60              7
# 2           11         53          15          59              6
# 3           11         52          14          58              6
# 4           11         52          15          59              5
# ...        ...        ...         ...         ...            ...
# 1459         8         47          20          68             14
# 1460         9         48          20          67             14
# 1461        10         49          19          66             13
# 1462        10         50          18          65             12
# 1463        11         52          18          64             11
#
#       WindGustKmph  FeelsLikeC  FeelsLikeF
# 0               12          16          61
# 1               11          16          60
# 2               10          15          59
# 3                9          14          58
# 4                8          15          59
# ...            ...         ...         ...
# 1459            23          20          68
# 1460            22          20          67
# 1461            22          19          66
# 1462            20          18          65
# 1463            18          18          64
#
# [1464 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['loc_id', 'date', 'time', 'isdaytime', 'tempC', 'tempF',
#        'windspeedMiles', 'windspeedKmph', 'winddirdegree', 'winddir16point',
#        'weatherCode', 'weatherIconUrl', 'weatherDesc', 'precipMM',
#        'precipInches', 'humidity', 'visibilityKm', 'visibilityMiles',
#        'pressureMB', 'pressureInches', 'cloudcover', 'HeatIndexC',
#        'HeatIndexF', 'DewPointC', 'DewPointF', 'WindChillC', 'WindChillF',
#        'WindGustMiles', 'WindGustKmph', 'FeelsLikeC', 'FeelsLikeF'],
#       dtype='object')

# %%
df = df.drop(["loc_id","time","date"], axis=1)

# %%
def is_numeric(col):
    try:
      # df_min_max_scaled = df_min_max_scaled.drop(["date", "time"], axis=1)
      pd.to_numeric(col)
      return True
    except:
        return False

# %%
#Find all the numerical columns
numeric_columns = []
for column in df.columns:
  if(is_numeric(df[column])):
    numeric_columns.append(column)

# %%
print(numeric_columns)
# Out:
# ['tempC', 'tempF', 'windspeedMiles', 'windspeedKmph', 'winddirdegree', 'weatherCode', 'precipMM', 'precipInches', 'humidity', 'visibilityKm', 'visibilityMiles', 'pressureMB', 'pressureInches', 'cloudcover', 'HeatIndexC', 'HeatIndexF', 'DewPointC', 'DewPointF', 'WindChillC', 'WindChillF', 'WindGustMiles', 'WindGustKmph', 'FeelsLikeC', 'FeelsLikeF']

# %%
#normalization of nuerical data i.e between 0 and 1
#MinMax Scaling for all umeric colums
#MinMAx scaling allows us to get information about the significance of each entry in a column
df_min_max_scaled = df.copy()
for numeric_column in numeric_columns:
  df_min_max_scaled[numeric_column] = (df_min_max_scaled[numeric_column] - df_min_max_scaled[numeric_column].min()) / (df_min_max_scaled[numeric_column].max() - df_min_max_scaled[numeric_column].min())

# %%
df_min_max_scaled.head()
# We do ot need the location id at this point

# %%
#Total number of unique values in a column
value_counts = []
value_counts_dict = {}
for column in numeric_columns:
  value_counts_dict[column] = len(set(df_min_max_scaled[column]))
  value_counts.append(len(set(df_min_max_scaled[column])))

print(value_counts_dict)
# Out:
# {'tempC': 30, 'tempF': 48, 'windspeedMiles': 22, 'windspeedKmph': 33, 'winddirdegree': 326, 'weatherCode': 15, 'precipMM': 35, 'precipInches': 5, 'humidity': 66, 'visibilityKm': 19, 'visibilityMiles': 12, 'pressureMB': 34, 'pressureInches': 2, 'cloudcover': 101, 'HeatIndexC': 28, 'HeatIndexF': 45, 'DewPointC': 17, 'DewPointF': 29, 'WindChillC': 30, 'WindChillF': 51, 'WindGustMiles': 32, 'WindGustKmph': 47, 'FeelsLikeC': 31, 'FeelsLikeF': 50}

# %%
value_sigificance = []
for value in value_counts:
  value_sigificance.append(value/sum(value_counts))

# %%
#Minmax normalization of column unique value count
# this will enable us to get the significance of each individual column

import numpy as np

data = np.array(value_sigificance)
normalizedData = (data-np.min(data))/(np.max(data)-np.min(data))
print(normalizedData)
# Out:
# [0.08641975 0.14197531 0.0617284  0.09567901 1.         0.04012346
#  0.10185185 0.00925926 0.19753086 0.05246914 0.0308642  0.09876543
#  0.         0.30555556 0.08024691 0.13271605 0.0462963  0.08333333
#  0.08641975 0.15123457 0.09259259 0.13888889 0.08950617 0.14814815]

# %%
df_min_max_scaled
# Out:
#      isdaytime     tempC     tempF  windspeedMiles  windspeedKmph  \
# 0           no  0.366667  0.370370        0.285714        0.28125
# 1           no  0.366667  0.351852        0.285714        0.25000
# 2           no  0.333333  0.333333        0.238095        0.25000
# 3           no  0.333333  0.314815        0.238095        0.21875
# 4           no  0.333333  0.333333        0.190476        0.18750
# ...        ...       ...       ...             ...            ...
# 1459        no  0.500000  0.500000        0.523810        0.53125
# 1460        no  0.500000  0.481481        0.523810        0.50000
# 1461        no  0.466667  0.462963        0.476190        0.43750
# 1462        no  0.433333  0.444444        0.428571        0.43750
# 1463        no  0.433333  0.425926        0.380952        0.40625
#
#       winddirdegree winddir16point  weatherCode  \
# 0          0.640227             SW     0.010870
# 1          0.645892             SW     0.010870
# 2          0.654391             SW     0.010870
# 3          0.660057             SW     0.010870
# 4          0.643059             SW     0.010870
# ...             ...            ...          ...
# 1459       0.730878              W     0.228261
# 1460       0.725212            WSW     0.010870
# 1461       0.722380            WSW     0.010870
# 1462       0.725212            WSW     0.010870
# 1463       0.728045            WSW     0.010870
#
#                                          weatherIconUrl           weatherDesc  \
# 0     https://cdn.worldweatheronline.net/images/wsym...         Partly cloudy
# 1     https://cdn.worldweatheronline.net/images/wsym...         Partly cloudy
# 2     https://cdn.worldweatheronline.net/images/wsym...         Partly cloudy
# 3     https://cdn.worldweatheronline.net/images/wsym...         Partly cloudy
# 4     https://cdn.worldweatheronline.net/images/wsym...         Partly cloudy
# ...                                                 ...                   ...
# 1459  https://cdn.worldweatheronline.net/images/wsym...  Patchy rain possible
# 1460  https://cdn.worldweatheronline.net/images/wsym...         Partly cloudy
# 1461  https://cdn.worldweatheronline.net/images/wsym...         Partly cloudy
# 1462  https://cdn.worldweatheronline.net/images/wsym...         Partly cloudy
# 1463  https://cdn.worldweatheronline.net/images/wsym...         Partly cloudy
#
#       ...  HeatIndexC  HeatIndexF  DewPointC  DewPointF  WindChillC  \
# 0     ...    0.259259    0.255319     0.5000   0.500000    0.366667
# 1     ...    0.259259    0.234043     0.5000   0.464286    0.366667
# 2     ...    0.222222    0.212766     0.4375   0.464286    0.333333
# 3     ...    0.222222    0.191489     0.4375   0.428571    0.300000
# 4     ...    0.222222    0.212766     0.4375   0.428571    0.333333
# ...   ...         ...         ...        ...        ...         ...
# 1459  ...    0.407407    0.404255     0.2500   0.250000    0.500000
# 1460  ...    0.407407    0.382979     0.3125   0.285714    0.500000
# 1461  ...    0.370370    0.361702     0.3750   0.321429    0.466667
# 1462  ...    0.333333    0.340426     0.3750   0.357143    0.433333
# 1463  ...    0.333333    0.319149     0.4375   0.428571    0.433333
#
#       WindChillF  WindGustMiles  WindGustKmph  FeelsLikeC  FeelsLikeF
# 0       0.370370        0.21875          0.22    0.354839    0.363636
# 1       0.351852        0.21875          0.20    0.354839    0.345455
# 2       0.333333        0.18750          0.18    0.322581    0.327273
# 3       0.314815        0.18750          0.16    0.290323    0.309091
# 4       0.333333        0.15625          0.14    0.322581    0.327273
# ...          ...            ...           ...         ...         ...
# 1459    0.500000        0.43750          0.44    0.483871    0.490909
# 1460    0.481481        0.43750          0.42    0.483871    0.472727
# 1461    0.462963        0.40625          0.42    0.451613    0.454545
# 1462    0.444444        0.37500          0.38    0.419355    0.436364
# 1463    0.425926        0.34375          0.34    0.419355    0.418182
#
# [1464 rows x 28 columns]

# %%
column_significance = {}

for i in range(len(normalizedData)):
  column_significance[numeric_columns[i]] = normalizedData[i]

column_significance
# Out:
# {'tempC': 0.08641975308641975,
#  'tempF': 0.1419753086419753,
#  'windspeedMiles': 0.0617283950617284,
#  'windspeedKmph': 0.09567901234567901,
#  'winddirdegree': 1.0,
#  'weatherCode': 0.04012345679012346,
#  'precipMM': 0.10185185185185185,
#  'precipInches': 0.009259259259259259,
#  'humidity': 0.19753086419753088,
#  'visibilityKm': 0.05246913580246914,
#  'visibilityMiles': 0.0308641975308642,
#  'pressureMB': 0.09876543209876543,
#  'pressureInches': 0.0,
#  'cloudcover': 0.3055555555555556,
#  'HeatIndexC': 0.08024691358024691,
#  'HeatIndexF': 0.13271604938271606,
#  'DewPointC': 0.046296296296296294,
#  'DewPointF': 0.08333333333333333,
#  'WindChillC': 0.08641975308641975,
#  'WindChillF': 0.15123456790123457,
#  'WindGustMiles': 0.09259259259259259,
#  'WindGustKmph': 0.1388888888888889,
#  'FeelsLikeC': 0.08950617283950617,
#  'FeelsLikeF': 0.14814814814814817}

# %%
def get_entry_significance(parent_col, entry):
  if(str(entry) == 'nan'):
    return 0
  all_entries = len(df_min_max_scaled[parent_col])
  items = df_min_max_scaled[parent_col].value_counts()[entry]
  return items/all_entries

# %%
#GET sigificace of each etry in the 'table'
#We repeat the same techniques we used for the columns
# entry_significance = {}
# entry_significance_list = []
# for column in numeric_columns:
#   items = df_min_max_scaled[column]
#   respective = []
#   for item in items:
#     respective.append(get_entry_significance(column,item))
#   entry_significance_list.append(respective)
#   entry_significance[column] = respective

# %%
# for column in numeric_columns:
#   df_min_max_scaled[column] = entry_significance[column]

# %%
df_min_max_scaled.head()
#Unscaled significance values
# Out:
#   isdaytime     tempC     tempF  windspeedMiles  windspeedKmph  winddirdegree  \
# 0        no  0.366667  0.370370        0.285714        0.28125       0.640227
# 1        no  0.366667  0.351852        0.285714        0.25000       0.645892
# 2        no  0.333333  0.333333        0.238095        0.25000       0.654391
# 3        no  0.333333  0.314815        0.238095        0.21875       0.660057
# 4        no  0.333333  0.333333        0.190476        0.18750       0.643059
#
#   winddir16point  weatherCode  \
# 0             SW      0.01087
# 1             SW      0.01087
# 2             SW      0.01087
# 3             SW      0.01087
# 4             SW      0.01087
#
#                                       weatherIconUrl    weatherDesc  ...  \
# 0  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 1  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 2  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 3  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 4  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
#
#    HeatIndexC  HeatIndexF  DewPointC  DewPointF  WindChillC  WindChillF  \
# 0    0.259259    0.255319     0.5000   0.500000    0.366667    0.370370
# 1    0.259259    0.234043     0.5000   0.464286    0.366667    0.351852
# 2    0.222222    0.212766     0.4375   0.464286    0.333333    0.333333
# 3    0.222222    0.191489     0.4375   0.428571    0.300000    0.314815
# 4    0.222222    0.212766     0.4375   0.428571    0.333333    0.333333
#
#    WindGustMiles  WindGustKmph  FeelsLikeC  FeelsLikeF
# 0        0.21875          0.22    0.354839    0.363636
# 1        0.21875          0.20    0.354839    0.345455
# 2        0.18750          0.18    0.322581    0.327273
# 3        0.18750          0.16    0.290323    0.309091
# 4        0.15625          0.14    0.322581    0.327273
#
# [5 rows x 28 columns]

# %%
#Normalize values to be between 0 and 1
for numeric_column in numeric_columns:
  df_min_max_scaled[numeric_column] = (df_min_max_scaled[numeric_column] - df_min_max_scaled[numeric_column].min()) / (df_min_max_scaled[numeric_column].max() - df_min_max_scaled[numeric_column].min())

# %%
#now we have a table populated with significance values that have een scaled to be between 0 and 1
df_min_max_scaled.head()
# Out:
#   isdaytime     tempC     tempF  windspeedMiles  windspeedKmph  winddirdegree  \
# 0        no  0.366667  0.370370        0.285714        0.28125       0.640227
# 1        no  0.366667  0.351852        0.285714        0.25000       0.645892
# 2        no  0.333333  0.333333        0.238095        0.25000       0.654391
# 3        no  0.333333  0.314815        0.238095        0.21875       0.660057
# 4        no  0.333333  0.333333        0.190476        0.18750       0.643059
#
#   winddir16point  weatherCode  \
# 0             SW      0.01087
# 1             SW      0.01087
# 2             SW      0.01087
# 3             SW      0.01087
# 4             SW      0.01087
#
#                                       weatherIconUrl    weatherDesc  ...  \
# 0  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 1  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 2  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 3  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 4  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
#
#    HeatIndexC  HeatIndexF  DewPointC  DewPointF  WindChillC  WindChillF  \
# 0    0.259259    0.255319     0.5000   0.500000    0.366667    0.370370
# 1    0.259259    0.234043     0.5000   0.464286    0.366667    0.351852
# 2    0.222222    0.212766     0.4375   0.464286    0.333333    0.333333
# 3    0.222222    0.191489     0.4375   0.428571    0.300000    0.314815
# 4    0.222222    0.212766     0.4375   0.428571    0.333333    0.333333
#
#    WindGustMiles  WindGustKmph  FeelsLikeC  FeelsLikeF
# 0        0.21875          0.22    0.354839    0.363636
# 1        0.21875          0.20    0.354839    0.345455
# 2        0.18750          0.18    0.322581    0.327273
# 3        0.18750          0.16    0.290323    0.309091
# 4        0.15625          0.14    0.322581    0.327273
#
# [5 rows x 28 columns]

# %%
# df_min_max_scaled = df_min_max_scaled.drop(["date", "time"], axis=1)

# %%
# #Adding the column significance to the row significance

# for column in numeric_columns:
#   df_min_max_scaled[column] = df_min_max_scaled[column] * column_significance[column]

# %%
df_min_max_scaled.head(20)
# Out:
#    isdaytime     tempC     tempF  windspeedMiles  windspeedKmph  \
# 0         no  0.366667  0.370370        0.285714        0.28125
# 1         no  0.366667  0.351852        0.285714        0.25000
# 2         no  0.333333  0.333333        0.238095        0.25000
# 3         no  0.333333  0.314815        0.238095        0.21875
# 4         no  0.333333  0.333333        0.190476        0.18750
# 5         no  0.366667  0.370370        0.190476        0.15625
# 6         no  0.400000  0.388889        0.190476        0.15625
# 7         no  0.433333  0.425926        0.190476        0.15625
# 8        yes  0.466667  0.481481        0.190476        0.15625
# 9        yes  0.533333  0.518519        0.190476        0.18750
# 10       yes  0.566667  0.574074        0.238095        0.25000
# 11       yes  0.633333  0.629630        0.285714        0.28125
# 12       yes  0.666667  0.685185        0.333333        0.34375
# 13       yes  0.666667  0.685185        0.380952        0.37500
# 14       yes  0.700000  0.685185        0.428571        0.40625
# 15       yes  0.700000  0.685185        0.428571        0.43750
# 16       yes  0.666667  0.666667        0.428571        0.40625
# 17        no  0.666667  0.666667        0.428571        0.40625
# 18        no  0.633333  0.648148        0.428571        0.40625
# 19        no  0.600000  0.611111        0.380952        0.37500
#
#     winddirdegree winddir16point  weatherCode  \
# 0        0.640227             SW      0.01087
# 1        0.645892             SW      0.01087
# 2        0.654391             SW      0.01087
# 3        0.660057             SW      0.01087
# 4        0.643059             SW      0.01087
# 5        0.628895             SW      0.01087
# 6        0.611898             SW      0.01087
# 7        0.600567             SW      0.01087
# 8        0.592068            SSW      0.01087
# 9        0.580737            SSW      0.01087
# 10       0.572238            SSW      0.01087
# 11       0.563739            SSW      0.01087
# 12       0.558074            SSW      0.01087
# 13       0.560907            SSW      0.01087
# 14       0.563739            SSW      0.01087
# 15       0.566572            SSW      0.01087
# 16       0.555241            SSW      0.01087
# 17       0.546742            SSW      0.01087
# 18       0.538244            SSW      0.01087
# 19       0.515581              S      0.01087
#
#                                        weatherIconUrl    weatherDesc  ...  \
# 0   https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 1   https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 2   https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 3   https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 4   https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 5   https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 6   https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 7   https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 8   https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 9   https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 10  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 11  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 12  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 13  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 14  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 15  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 16  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 17  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 18  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
# 19  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy  ...
#
#     HeatIndexC  HeatIndexF  DewPointC  DewPointF  WindChillC  WindChillF  \
# 0     0.259259    0.255319     0.5000   0.500000    0.366667    0.370370
# 1     0.259259    0.234043     0.5000   0.464286    0.366667    0.351852
# 2     0.222222    0.212766     0.4375   0.464286    0.333333    0.333333
# 3     0.222222    0.191489     0.4375   0.428571    0.300000    0.314815
# 4     0.222222    0.212766     0.4375   0.428571    0.333333    0.333333
# 5     0.259259    0.255319     0.4375   0.428571    0.366667    0.351852
# 6     0.296296    0.276596     0.4375   0.464286    0.400000    0.388889
# 7     0.333333    0.319149     0.4375   0.392857    0.433333    0.425926
# 8     0.370370    0.382979     0.3750   0.357143    0.466667    0.481481
# 9     0.444444    0.425532     0.3750   0.321429    0.533333    0.518519
# 10    0.481481    0.489362     0.3125   0.321429    0.566667    0.574074
# 11    0.555556    0.553191     0.3125   0.321429    0.633333    0.629630
# 12    0.592593    0.617021     0.3125   0.285714    0.666667    0.685185
# 13    0.629630    0.617021     0.3750   0.357143    0.666667    0.685185
# 14    0.629630    0.617021     0.4375   0.428571    0.700000    0.685185
# 15    0.629630    0.638298     0.5000   0.500000    0.700000    0.685185
# 16    0.629630    0.638298     0.5625   0.571429    0.666667    0.666667
# 17    0.629630    0.617021     0.6250   0.607143    0.666667    0.666667
# 18    0.629630    0.617021     0.6875   0.678571    0.633333    0.648148
# 19    0.592593    0.595745     0.6875   0.714286    0.600000    0.611111
#
#     WindGustMiles  WindGustKmph  FeelsLikeC  FeelsLikeF
# 0         0.21875          0.22    0.354839    0.363636
# 1         0.21875          0.20    0.354839    0.345455
# 2         0.18750          0.18    0.322581    0.327273
# 3         0.18750          0.16    0.290323    0.309091
# 4         0.15625          0.14    0.322581    0.327273
# 5         0.15625          0.12    0.354839    0.345455
# 6         0.12500          0.10    0.387097    0.381818
# 7         0.12500          0.12    0.419355    0.418182
# 8         0.15625          0.12    0.451613    0.472727
# 9         0.15625          0.14    0.516129    0.509091
# 10        0.18750          0.18    0.548387    0.563636
# 11        0.21875          0.22    0.612903    0.618182
# 12        0.28125          0.26    0.645161    0.672727
# 13        0.28125          0.28    0.677419    0.672727
# 14        0.31250          0.30    0.677419    0.672727
# 15        0.34375          0.32    0.677419    0.690909
# 16        0.31250          0.32    0.677419    0.690909
# 17        0.31250          0.30    0.677419    0.672727
# 18        0.31250          0.30    0.677419    0.672727
# 19        0.31250          0.28    0.645161    0.654545
#
# [20 rows x 28 columns]

# %%
df_num = df_min_max_scaled[numeric_columns]
# df_num.drop(["loc_id"], axis=1)

# %%
#Creates a list of all non numeric colums
non_numeric = set(df.columns).difference(set(numeric_columns))

# %%
df_non_numeric = df[list(non_numeric)]

# %%
df_non_numeric.head()
# Out:
#                                       weatherIconUrl    weatherDesc  \
# 0  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy
# 1  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy
# 2  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy
# 3  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy
# 4  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy
#
#   winddir16point isdaytime
# 0             SW        no
# 1             SW        no
# 2             SW        no
# 3             SW        no
# 4             SW        no

# %%
df_num.head()
# Out:
#       tempC     tempF  windspeedMiles  windspeedKmph  winddirdegree  \
# 0  0.366667  0.370370        0.285714        0.28125       0.640227
# 1  0.366667  0.351852        0.285714        0.25000       0.645892
# 2  0.333333  0.333333        0.238095        0.25000       0.654391
# 3  0.333333  0.314815        0.238095        0.21875       0.660057
# 4  0.333333  0.333333        0.190476        0.18750       0.643059
#
#    weatherCode  precipMM  precipInches  humidity  visibilityKm  ...  \
# 0      0.01087       0.0           0.0  0.772727      0.444444  ...
# 1      0.01087       0.0           0.0  0.787879      0.444444  ...
# 2      0.01087       0.0           0.0  0.803030      0.444444  ...
# 3      0.01087       0.0           0.0  0.803030      0.444444  ...
# 4      0.01087       0.0           0.0  0.772727      0.444444  ...
#
#    HeatIndexC  HeatIndexF  DewPointC  DewPointF  WindChillC  WindChillF  \
# 0    0.259259    0.255319     0.5000   0.500000    0.366667    0.370370
# 1    0.259259    0.234043     0.5000   0.464286    0.366667    0.351852
# 2    0.222222    0.212766     0.4375   0.464286    0.333333    0.333333
# 3    0.222222    0.191489     0.4375   0.428571    0.300000    0.314815
# 4    0.222222    0.212766     0.4375   0.428571    0.333333    0.333333
#
#    WindGustMiles  WindGustKmph  FeelsLikeC  FeelsLikeF
# 0        0.21875          0.22    0.354839    0.363636
# 1        0.21875          0.20    0.354839    0.345455
# 2        0.18750          0.18    0.322581    0.327273
# 3        0.18750          0.16    0.290323    0.309091
# 4        0.15625          0.14    0.322581    0.327273
#
# [5 rows x 24 columns]

# %%
import torch
row_attention_matrices = []

for column in df_num.columns:
  Table_1 = []
  for column_2 in df_num.columns:
    c = df_num[column] * df_num[column_2]
    Table_1.append(torch.tensor(list(c)))
  row_attention_matrices.append(torch.stack(Table_1))
x = torch.stack(row_attention_matrices)
x_T = torch.transpose(x,2,0)
print(f"GENERAL SHAPE: {x_T.shape}")
print(f"SHAPE OF A SINGLE LAYER: {x_T[6].shape}")
# Out:
# GENERAL SHAPE: torch.Size([1464, 24, 24])
# SHAPE OF A SINGLE LAYER: torch.Size([24, 24])

# %% [markdown]
# A major problem we face with our data is the fact that most of our data is numeric and not text. All the systems that summarization system used, are specifically made for text data. This means that we have somehow have to make our numeric data behave like text so that we can summarize it. Upto this point, we have been working to make our numeric data behave like text data. And now we have finally reached the last part of the process. From the above output, you can see that there are 61  30x30 matrices. Each 30x30 matrix is a result of us calculating the signnificance of our numeric columns against themselves. 1464 is the number of rows. These 30X30 matrices are important since they will help us get the embeddings for our numeric data as we pass them through an RNN model.

# %%
all = df_num.values.tolist()
all_test = all[int(len(all) * 0.8):]
all = all[:int(len(all) * 0.8)]
print(all[0])
# Out:
# [0.36666666666666664, 0.37037037037037035, 0.2857142857142857, 0.28125, 0.6402266288951841, 0.010869565217391304, 0.0, 0.0, 0.7727272727272727, 0.4444444444444444, 0.45454545454545453, 0.7878787878787878, 1.0, 0.07, 0.25925925925925924, 0.2553191489361702, 0.5, 0.5, 0.36666666666666664, 0.37037037037037035, 0.21875, 0.22, 0.3548387096774194, 0.36363636363636365]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
import numpy as np
from numpy.linalg import norm

def COS_SIM(A,B):
  A = np.array(A)
  B = np.array(B)
  cosine = np.dot(A,B)/(norm(A)*norm(B))
  return cosine

# %%
'''Preprocessing the text part of our data'''
# Out:
# 'Preprocessing the text part of our data'

# %%
len(all)
# Out:
# 1171

# %%
#Non numeric data
df_non_numeric.head()
# Out:
#                                       weatherIconUrl    weatherDesc  \
# 0  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy
# 1  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy
# 2  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy
# 3  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy
# 4  https://cdn.worldweatheronline.net/images/wsym...  Partly cloudy
#
#   winddir16point isdaytime
# 0             SW        no
# 1             SW        no
# 2             SW        no
# 3             SW        no
# 4             SW        no

# %%
df_non_numeric = df_non_numeric.drop(["weatherIconUrl"], axis=1)
df_non_numeric
#We droped the icon url since we do not need it for out use case
# Out:
#                weatherDesc winddir16point isdaytime
# 0            Partly cloudy             SW        no
# 1            Partly cloudy             SW        no
# 2            Partly cloudy             SW        no
# 3            Partly cloudy             SW        no
# 4            Partly cloudy             SW        no
# ...                    ...            ...       ...
# 1459  Patchy rain possible              W        no
# 1460         Partly cloudy            WSW        no
# 1461         Partly cloudy            WSW        no
# 1462         Partly cloudy            WSW        no
# 1463         Partly cloudy            WSW        no
#
# [1464 rows x 3 columns]

# %%
#Get a list of words
all_words = []
for column in df_non_numeric.columns:
  column_words = set(df_non_numeric[column])
  all_words.extend(list(column_words))

print(all_words)
# Out:
# ['Partly cloudy', 'Light rain', 'Sunny', 'Moderate rain', 'Overcast', 'Patchy rain possible', 'Clear', 'Cloudy', 'Moderate or heavy rain shower', 'Torrential rain shower', 'Light rain shower', 'Moderate rain at times', 'Patchy light rain', 'Moderate or heavy rain with thunder', 'Heavy rain', 'Light drizzle', 'SSW', 'S', 'NNE', 'ESE', 'N', 'NNW', 'ENE', 'WSW', 'SE', 'SW', 'E', 'SSE', 'WNW', 'NW', 'W', 'NE', 'yes', 'no']

# %%
#Give each entry a number that will represent it
WORD_2_TOKEN = {}
TOKEN_2_WORD = {}

def Tokenize(word, i):
  WORD_2_TOKEN[word] = i
  TOKEN_2_WORD[i] = word
  return

def encode(row):
  encoded = []
  for word in row:
    encoded.append(WORD_2_TOKEN[word])
  return encoded

def decode(row_encoded):
  decoded = []
  for word in row_encoded:
    decoded.append(TOKEN_2_WORD[word])
  return decoded

# %%
for i in range(len(all_words)):
  Tokenize(all_words[i], i)

# %%
print(f"Encode example: {encode(['Light rain shower','Partly cloudy'])}")
# Out:
# Encode example: [10, 0]

# %%
print(f"Decode example: {decode([29,19])}")
# Out:
# Decode example: ['NW', 'ESE']

# %% [markdown]
# Now our text data is ready to be passed to a deep learning model.

# %% [markdown]
# During training, we will pass the numerical representation for our word through an embedding layer which will produce word embeddings. As for the part concerning numeric data, we will take our 26X26 matrix and put it through a softmax layer and then through a linear layer to obtain the embeddings for our

# %%
import torch
def tensorfy(chosen_sequence):
  csq = []
  for x_seq in chosen_sequence:
    csq.append(torch.tensor(x_seq))
  return csq

# %%
from random import randint

def get_sequence(SEQ_LEN):
  start_point = randint(0,( len(all) - SEQ_LEN) -1)
  chosen_sequence = all[start_point: start_point + SEQ_LEN]
  return tensorfy(chosen_sequence),chosen_sequence

def get_test_sequence(SEQ_LEN):
  start_point = randint(0,( len(all_test) - SEQ_LEN) -1)
  chosen_sequence = all_test[start_point: start_point + SEQ_LEN]
  return tensorfy(chosen_sequence),chosen_sequence

# %%
def get_max_index(src_input):
  local = src_input.copy()
  local.sort()
  return local[len(local) - 2]

# %%
def get_maxes(cos_sims):
  maxes = []
  for cos_sim in cos_sims:
    maxes.append(torch.tensor(get_max_index(cos_sim)))
  return torch.stack(maxes)

# %%
def get_batch(Batch_Size,chunk="train"):
  Batch_Size = 32
  batch = []
  labels = []
  vanilla_batch = []
  for _ in range(Batch_Size):
    if(chunk == "train"):
      src_input, vnl_input = get_sequence(64)
    else:
      src_input, vnl_input = get_test_sequence(64)
    # labels.append(torch.tensor(get_max_index(src_input)))
    src_input = torch.stack(src_input).transpose(1,0)
    cos_sims = cosine_similarity(detensorfy(src_input))
    labels.append(get_maxes(cos_sims))
    batch.append(src_input)
    vanilla_batch.append(vnl_input)
  return torch.stack(batch),torch.stack(labels)

# %%
def detensorfy(tensor_array):
  arr = []
  for tnsr in tensor_array:
    arr.append(tnsr.tolist())
  return arr

# %%
import math
import torch.nn.functional as F

# Given Query, Key, Value, calculate the final weighted value
def scaled_dot_product_attention(q, k, v, mask=None, dropout=None):
    attention_scores = torch.matmul(q, k.transpose(-2, -1))/math.sqrt(q.shape[-1])
    if mask is not None:
        attention_scores = attention_scores.masked_fill(mask == 0, value=-1e9)

    # Softmax along the last dimension
    attention_weights = F.softmax(attention_scores, dim=-1)

    if dropout is not None:
        attention_weights = dropout(attention_weights)

    output = torch.matmul(attention_weights, v)
    return output

# %%
class MultiHeadAttention(torch.nn.Module):
    def __init__(self, n_heads, d_model, dropout=0.1):
        super().__init__()

        self.n_heads = n_heads
        self.d_model = d_model
        self.d_k = self.d_k = self.d_v = d_model//n_heads

        # self attention linear layers
        # Linear layers for q, k, v vectors generation in different heads
        self.q_linear_layers = []
        self.k_linear_layers = []
        self.v_linear_layers = []
        for i in range(n_heads):

            self.q_linear_layers.append(torch.nn.Linear(d_model, self.d_k).to(device))
            self.k_linear_layers.append(torch.nn.Linear(d_model, self.d_k).to(device))
            self.v_linear_layers.append(torch.nn.Linear(d_model, self.d_v).to(device))

        self.dropout = torch.nn.Dropout(dropout)
        self.out = torch.nn.Linear(n_heads*self.d_v, d_model)

    def forward(self, q, k, v, mask=None):
        multi_head_attention_outputs = []
        for q_linear, k_linear, v_linear in zip(self.q_linear_layers,
                                                self.k_linear_layers,
                                                self.v_linear_layers):
            new_q = q_linear(q)
            new_k = k_linear(k)
            new_v = v_linear(v)


            head_v = scaled_dot_product_attention(new_q, new_k, new_v, mask, self.dropout)  # (batch_size, seq_len, d_v)
            multi_head_attention_outputs.append(head_v)

        concat = torch.cat(multi_head_attention_outputs, -1)  # (batch_size, seq_len, n_heads*d_v)

        # Linear layer to recover to original shap
        output = self.out(concat)  # (batch_size, seq_len, d_model)

        return output

# %%
class FeedForward(torch.nn.Module):
    def __init__(self, d_model, d_ff=2048, dropout=0.1):
        super().__init__()

        self.linear_1 = torch.nn.Linear(d_model, d_ff)
        self.dropout = torch.nn.Dropout(dropout)
        self.linear_2 = torch.nn.Linear(d_ff, d_model)

    def forward(self, x):
        x = self.dropout(F.relu(self.linear_1(x)))
        x = self.linear_2(x)
        return x

# %%
class LayerNorm(torch.nn.Module):
    def __init__(self, d_model, eps=1e-6):
        super().__init__()
        self.d_model = d_model
        self.alpha = torch.nn.Parameter(torch.ones(self.d_model))
        self.beta = torch.nn.Parameter(torch.zeros(self.d_model))
        self.eps = eps

    def forward(self, x):
        # x size: (batch_size, seq_len, d_model)
        x_hat = (x - x.mean(dim=-1, keepdim=True))/(x.std(dim=-1, keepdim=True) + self.eps)
        x_tilde = self.alpha*x_hat + self.beta
        return x_tilde

# %%
class EncoderLayer(torch.nn.Module):
    def __init__(self, d_model, n_heads, dropout=0.1):
        super().__init__()
        self.d_model = d_model
        self.norm_1 = LayerNorm(d_model)
        self.norm_2 = LayerNorm(d_model)
        self.multi_head_attention = MultiHeadAttention(n_heads, d_model).to(device)
        self.feed_forward = FeedForward(d_model)
        self.dropout_1 = torch.nn.Dropout(dropout).to(device)
        self.dropout_2 = torch.nn.Dropout(dropout).to(device)

    def forward(self, x, mask):
        #import pdb; pdb.set_trace()

        x = x + self.dropout_1(self.multi_head_attention(x, x, x, mask).to(device)).to(device)
        x = self.norm_1(x)
        x = x + self.dropout_2(self.feed_forward(x))
        x = self.norm_2(x)
        return x

# %%
class MLP(torch.nn.Module):
  def __init__(self,d_model):
    super().__init__()
    self.linear = torch.nn.Linear(d_model,1024)
    self.linear_2 = torch.nn.Linear(1024,24)

  def forward(self, x):
    x = self.linear(x)
    x = F.relu(x)
    x = self.linear_2(x)
    return x

# %%
import copy

def clone_layer(module, N):
    return torch.nn.ModuleList([copy.deepcopy(module) for i in range(N)])

# %%
class Encoder(torch.nn.Module):
    def __init__(self, d_model, N, n_heads):
        super().__init__()
        self.encoder_layers = clone_layer(EncoderLayer(d_model, n_heads).to(device), N).to(device)
        self.norm = LayerNorm(d_model).to(device)
        self.MLP = MLP(64 * 24)
    def forward(self, src_embeddings, mask):
        x = src_embeddings
        for encoder in self.encoder_layers:
            x = encoder(x, mask)
        x = self.norm(x)
        x = torch.flatten(x, 1,2)
        x = self.MLP(x)
        x = F.tanh(x)
        return x

# %%
d_model = 64
n_heads = 2
N = 1

# %%
device = "cuda"

# %%
Train_model = Encoder(d_model, N, n_heads).to(device)

# %%
for p in Train_model.parameters():
    if p.dim() > 1:
        torch.nn.init.xavier_uniform(p)
# Out:
# <ipython-input-58-76a1a86bf4b2>:3: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   torch.nn.init.xavier_uniform(p)

# %%
optimizer = torch.optim.Adam(Train_model.parameters(),lr=1e-5)

# %%
device = "cuda"

# %%
criterion = torch.nn.MSELoss()

# %%
train_losses = []
epochs = 100
Train_model.train()
i = 0
for e in range(epochs):
  for _ in range(40):
    batch, labels = get_batch(32, chunk="train")
    preds = Train_model(batch.to(device),None)
    optimizer.zero_grad()
    loss = criterion(preds, labels.to(device).float())
    train_losses.append(loss.item())
    loss.backward()
    optimizer.step()
    i += 1
    if(i % 10 == 0):
      print(f"[-] Train_loss is {np.mean(train_losses)} iteration is {i} on epoch {e}")
      train_losses = []
  i = 0
# Out:
# [-] Train_loss is 0.9132574915885925 iteration is 10 on epoch 0
# [-] Train_loss is 0.5284286588430405 iteration is 20 on epoch 0
# [-] Train_loss is 0.29381077736616135 iteration is 30 on epoch 0
# [-] Train_loss is 0.15961432456970215 iteration is 40 on epoch 0
# [-] Train_loss is 0.07659434266388417 iteration is 10 on epoch 1
# [-] Train_loss is 0.04996607191860676 iteration is 20 on epoch 1
# [-] Train_loss is 0.04031508862972259 iteration is 30 on epoch 1
# [-] Train_loss is 0.03630891740322113 iteration is 40 on epoch 1
# [-] Train_loss is 0.03320783656090498 iteration is 10 on epoch 2
# [-] Train_loss is 0.02990451380610466 iteration is 20 on epoch 2
# [-] Train_loss is 0.029748969711363316 iteration is 30 on epoch 2
# [-] Train_loss is 0.027051948942244053 iteration is 40 on epoch 2
# [-] Train_loss is 0.028999513201415538 iteration is 10 on epoch 3
# [-] Train_loss is 0.02587423026561737 iteration is 20 on epoch 3
# [-] Train_loss is 0.023881350085139273 iteration is 30 on epoch 3
# [-] Train_loss is 0.026076947711408137 iteration is 40 on epoch 3
# [-] Train_loss is 0.02472375575453043 iteration is 10 on epoch 4
# [-] Train_loss is 0.02450067102909088 iteration is 20 on epoch 4
# [-] Train_loss is 0.02333858534693718 iteration is 30 on epoch 4
# [-] Train_loss is 0.022326101921498774 iteration is 40 on epoch 4
# [-] Train_loss is 0.022330774553120138 iteration is 10 on epoch 5
# [-] Train_loss is 0.02176344320178032 iteration is 20 on epoch 5
# [-] Train_loss is 0.022726174630224704 iteration is 30 on epoch 5
# [-] Train_loss is 0.020163324475288392 iteration is 40 on epoch 5
# [-] Train_loss is 0.019859579764306544 iteration is 10 on epoch 6
# [-] Train_loss is 0.019969177711755038 iteration is 20 on epoch 6
# [-] Train_loss is 0.020399924274533986 iteration is 30 on epoch 6
# [-] Train_loss is 0.019960191659629346 iteration is 40 on epoch 6
# [-] Train_loss is 0.01978470142930746 iteration is 10 on epoch 7
# [-] Train_loss is 0.018905308097600937 iteration is 20 on epoch 7
# [-] Train_loss is 0.01874323058873415 iteration is 30 on epoch 7
# [-] Train_loss is 0.01832866817712784 iteration is 40 on epoch 7
# [-] Train_loss is 0.017490724753588437 iteration is 10 on epoch 8
# [-] Train_loss is 0.018103054072707892 iteration is 20 on epoch 8
# [-] Train_loss is 0.01667483104392886 iteration is 30 on epoch 8
# [-] Train_loss is 0.01846968922764063 iteration is 40 on epoch 8
# [-] Train_loss is 0.016914710961282255 iteration is 10 on epoch 9
# [-] Train_loss is 0.016155768278986217 iteration is 20 on epoch 9
# [-] Train_loss is 0.017757122963666917 iteration is 30 on epoch 9
# [-] Train_loss is 0.015132418181747199 iteration is 40 on epoch 9
# [-] Train_loss is 0.017584191355854272 iteration is 10 on epoch 10
# [-] Train_loss is 0.015896838530898093 iteration is 20 on epoch 10
# [-] Train_loss is 0.017495553568005563 iteration is 30 on epoch 10
# [-] Train_loss is 0.016615498159080744 iteration is 40 on epoch 10
# [-] Train_loss is 0.01526561677455902 iteration is 10 on epoch 11
# [-] Train_loss is 0.016336293518543245 iteration is 20 on epoch 11
# [-] Train_loss is 0.015818462800234558 iteration is 30 on epoch 11
# [-] Train_loss is 0.01510351374745369 iteration is 40 on epoch 11
# [-] Train_loss is 0.015534065943211318 iteration is 10 on epoch 12
# [-] Train_loss is 0.015930440928786992 iteration is 20 on epoch 12
# [-] Train_loss is 0.015226950682699681 iteration is 30 on epoch 12
# [-] Train_loss is 0.01501606972888112 iteration is 40 on epoch 12
# [-] Train_loss is 0.014368613343685865 iteration is 10 on epoch 13
# [-] Train_loss is 0.014119991846382619 iteration is 20 on epoch 13
# [-] Train_loss is 0.014788726344704628 iteration is 30 on epoch 13
# [-] Train_loss is 0.013548098970204592 iteration is 40 on epoch 13
# [-] Train_loss is 0.013739017862826585 iteration is 10 on epoch 14
# [-] Train_loss is 0.01398391742259264 iteration is 20 on epoch 14
# [-] Train_loss is 0.013447514828294515 iteration is 30 on epoch 14
# [-] Train_loss is 0.013295701891183852 iteration is 40 on epoch 14
# [-] Train_loss is 0.013037173543125391 iteration is 10 on epoch 15
# [-] Train_loss is 0.01350623220205307 iteration is 20 on epoch 15
# [-] Train_loss is 0.013131268508732318 iteration is 30 on epoch 15
# [-] Train_loss is 0.011799111822620034 iteration is 40 on epoch 15
# [-] Train_loss is 0.01338003845885396 iteration is 10 on epoch 16
# [-] Train_loss is 0.013038347475230694 iteration is 20 on epoch 16
# [-] Train_loss is 0.01337142325937748 iteration is 30 on epoch 16
# [-] Train_loss is 0.013050678744912147 iteration is 40 on epoch 16
# [-] Train_loss is 0.012089022807776928 iteration is 10 on epoch 17
# [-] Train_loss is 0.01156922597438097 iteration is 20 on epoch 17
# [-] Train_loss is 0.01298185233026743 iteration is 30 on epoch 17
# [-] Train_loss is 0.012543592881411315 iteration is 40 on epoch 17
# [-] Train_loss is 0.011911118682473899 iteration is 10 on epoch 18
# [-] Train_loss is 0.011729235853999853 iteration is 20 on epoch 18
# [-] Train_loss is 0.01240896238014102 iteration is 30 on epoch 18
# [-] Train_loss is 0.01134654600173235 iteration is 40 on epoch 18
# [-] Train_loss is 0.012052240502089261 iteration is 10 on epoch 19
# [-] Train_loss is 0.012017632462084293 iteration is 20 on epoch 19
# [-] Train_loss is 0.01131306104362011 iteration is 30 on epoch 19
# [-] Train_loss is 0.010610866080969571 iteration is 40 on epoch 19
# [-] Train_loss is 0.011595050059258937 iteration is 10 on epoch 20
# [-] Train_loss is 0.011656736023724079 iteration is 20 on epoch 20
# [-] Train_loss is 0.011157932970672847 iteration is 30 on epoch 20
# [-] Train_loss is 0.011173694394528866 iteration is 40 on epoch 20
# [-] Train_loss is 0.011220743693411351 iteration is 10 on epoch 21
# [-] Train_loss is 0.010052249766886234 iteration is 20 on epoch 21
# [-] Train_loss is 0.010505145322531462 iteration is 30 on epoch 21
# [-] Train_loss is 0.010023272223770618 iteration is 40 on epoch 21
# [-] Train_loss is 0.010948639921844005 iteration is 10 on epoch 22
# [-] Train_loss is 0.010719905979931355 iteration is 20 on epoch 22
# [-] Train_loss is 0.010443736333400011 iteration is 30 on epoch 22
# [-] Train_loss is 0.01093033431097865 iteration is 40 on epoch 22
# [-] Train_loss is 0.01091493209823966 iteration is 10 on epoch 23
# [-] Train_loss is 0.010328217688947917 iteration is 20 on epoch 23
# [-] Train_loss is 0.010324032604694366 iteration is 30 on epoch 23
# [-] Train_loss is 0.009466672828420997 iteration is 40 on epoch 23
# [-] Train_loss is 0.010660745948553086 iteration is 10 on epoch 24
# [-] Train_loss is 0.010349528305232525 iteration is 20 on epoch 24
# [-] Train_loss is 0.009696382191032171 iteration is 30 on epoch 24
# [-] Train_loss is 0.009734935872256757 iteration is 40 on epoch 24
# [-] Train_loss is 0.009957813844084739 iteration is 10 on epoch 25
# [-] Train_loss is 0.00985523099079728 iteration is 20 on epoch 25
# [-] Train_loss is 0.008611880987882615 iteration is 30 on epoch 25
# [-] Train_loss is 0.009578339196741581 iteration is 40 on epoch 25
# [-] Train_loss is 0.009315153025090695 iteration is 10 on epoch 26
# [-] Train_loss is 0.00991548951715231 iteration is 20 on epoch 26
# [-] Train_loss is 0.009410716453567147 iteration is 30 on epoch 26
# [-] Train_loss is 0.009760944824665784 iteration is 40 on epoch 26
# [-] Train_loss is 0.00861438773572445 iteration is 10 on epoch 27
# [-] Train_loss is 0.008931886544451118 iteration is 20 on epoch 27
# [-] Train_loss is 0.008968149963766336 iteration is 30 on epoch 27
# [-] Train_loss is 0.008312258683145047 iteration is 40 on epoch 27
# [-] Train_loss is 0.009033816494047641 iteration is 10 on epoch 28
# [-] Train_loss is 0.00915155136026442 iteration is 20 on epoch 28
# [-] Train_loss is 0.009052968304604291 iteration is 30 on epoch 28
# [-] Train_loss is 0.008773799240589141 iteration is 40 on epoch 28
# [-] Train_loss is 0.008290536981076003 iteration is 10 on epoch 29
# [-] Train_loss is 0.008464536210522056 iteration is 20 on epoch 29
# [-] Train_loss is 0.008776777982711792 iteration is 30 on epoch 29
# [-] Train_loss is 0.009059104602783918 iteration is 40 on epoch 29
# [-] Train_loss is 0.00936578237451613 iteration is 10 on epoch 30
# [-] Train_loss is 0.008323447871953249 iteration is 20 on epoch 30
# [-] Train_loss is 0.007758799754083156 iteration is 30 on epoch 30
# [-] Train_loss is 0.008408001437783242 iteration is 40 on epoch 30
# [-] Train_loss is 0.008943341858685016 iteration is 10 on epoch 31
# [-] Train_loss is 0.007938236789777875 iteration is 20 on epoch 31
# [-] Train_loss is 0.00848421393893659 iteration is 30 on epoch 31
# [-] Train_loss is 0.008527664793655276 iteration is 40 on epoch 31
# [-] Train_loss is 0.008449452323839068 iteration is 10 on epoch 32
# [-] Train_loss is 0.008553676307201385 iteration is 20 on epoch 32
# [-] Train_loss is 0.00799195640720427 iteration is 30 on epoch 32
# [-] Train_loss is 0.007103956304490566 iteration is 40 on epoch 32
# [-] Train_loss is 0.007823762763291598 iteration is 10 on epoch 33
# [-] Train_loss is 0.00822373335249722 iteration is 20 on epoch 33
# [-] Train_loss is 0.008626049803569912 iteration is 30 on epoch 33
# [-] Train_loss is 0.008733291178941727 iteration is 40 on epoch 33
# [-] Train_loss is 0.007992342300713062 iteration is 10 on epoch 34
# [-] Train_loss is 0.00739987064152956 iteration is 20 on epoch 34
# [-] Train_loss is 0.008412067964673042 iteration is 30 on epoch 34
# [-] Train_loss is 0.007815564749762416 iteration is 40 on epoch 34
# [-] Train_loss is 0.007878891844302415 iteration is 10 on epoch 35
# [-] Train_loss is 0.007604761840775609 iteration is 20 on epoch 35
# [-] Train_loss is 0.007586214598268271 iteration is 30 on epoch 35
# [-] Train_loss is 0.007370815379545093 iteration is 40 on epoch 35
# [-] Train_loss is 0.007617628993466496 iteration is 10 on epoch 36
# [-] Train_loss is 0.007226775493472814 iteration is 20 on epoch 36
# [-] Train_loss is 0.007680190447717905 iteration is 30 on epoch 36
# [-] Train_loss is 0.00741191329434514 iteration is 40 on epoch 36
# [-] Train_loss is 0.006983027840033173 iteration is 10 on epoch 37
# [-] Train_loss is 0.0071534093003720045 iteration is 20 on epoch 37
# [-] Train_loss is 0.007223315490409732 iteration is 30 on epoch 37
# [-] Train_loss is 0.007481049932539463 iteration is 40 on epoch 37
# [-] Train_loss is 0.007057845592498779 iteration is 10 on epoch 38
# [-] Train_loss is 0.007456185529008508 iteration is 20 on epoch 38
# [-] Train_loss is 0.006929805222898722 iteration is 30 on epoch 38
# [-] Train_loss is 0.007253760891035199 iteration is 40 on epoch 38
# [-] Train_loss is 0.006844537053257227 iteration is 10 on epoch 39
# [-] Train_loss is 0.006911428784951568 iteration is 20 on epoch 39
# [-] Train_loss is 0.0072159387171268465 iteration is 30 on epoch 39
# [-] Train_loss is 0.006977780628949404 iteration is 40 on epoch 39
# [-] Train_loss is 0.006908477842807769 iteration is 10 on epoch 40
# [-] Train_loss is 0.007159010833129286 iteration is 20 on epoch 40
# [-] Train_loss is 0.007162917405366898 iteration is 30 on epoch 40
# [-] Train_loss is 0.006366857653483748 iteration is 40 on epoch 40
# [-] Train_loss is 0.007483395654708147 iteration is 10 on epoch 41
# [-] Train_loss is 0.006585202785208822 iteration is 20 on epoch 41
# [-] Train_loss is 0.00714966063387692 iteration is 30 on epoch 41
# [-] Train_loss is 0.0064615010749548675 iteration is 40 on epoch 41
# [-] Train_loss is 0.006234729662537575 iteration is 10 on epoch 42
# [-] Train_loss is 0.006466872291639447 iteration is 20 on epoch 42
# [-] Train_loss is 0.0061382965184748174 iteration is 30 on epoch 42
# [-] Train_loss is 0.006613910524174571 iteration is 40 on epoch 42
# [-] Train_loss is 0.006280119391158223 iteration is 10 on epoch 43
# [-] Train_loss is 0.006063307169824839 iteration is 20 on epoch 43
# [-] Train_loss is 0.006436695344746113 iteration is 30 on epoch 43
# [-] Train_loss is 0.006094809668138623 iteration is 40 on epoch 43
# [-] Train_loss is 0.006334570143371821 iteration is 10 on epoch 44
# [-] Train_loss is 0.006530691962689161 iteration is 20 on epoch 44
# [-] Train_loss is 0.0066714803222566845 iteration is 30 on epoch 44
# [-] Train_loss is 0.006299992371350527 iteration is 40 on epoch 44
# [-] Train_loss is 0.0067472257651388645 iteration is 10 on epoch 45
# [-] Train_loss is 0.006047875480726361 iteration is 20 on epoch 45
# [-] Train_loss is 0.005521295871585607 iteration is 30 on epoch 45
# [-] Train_loss is 0.006346372840926051 iteration is 40 on epoch 45
# [-] Train_loss is 0.006095158960670232 iteration is 10 on epoch 46
# [-] Train_loss is 0.006174904480576515 iteration is 20 on epoch 46
# [-] Train_loss is 0.006025269441306591 iteration is 30 on epoch 46
# [-] Train_loss is 0.0061007918324321505 iteration is 40 on epoch 46
# [-] Train_loss is 0.005691435700282454 iteration is 10 on epoch 47
# [-] Train_loss is 0.00610366384498775 iteration is 20 on epoch 47
# [-] Train_loss is 0.006174405477941037 iteration is 30 on epoch 47
# [-] Train_loss is 0.0056164939887821674 iteration is 40 on epoch 47
# [-] Train_loss is 0.0059706337284296754 iteration is 10 on epoch 48
# [-] Train_loss is 0.005883544543758034 iteration is 20 on epoch 48
# [-] Train_loss is 0.006287240562960506 iteration is 30 on epoch 48
# [-] Train_loss is 0.006344461673870682 iteration is 40 on epoch 48
# [-] Train_loss is 0.006230453448370099 iteration is 10 on epoch 49
# [-] Train_loss is 0.006255079573020339 iteration is 20 on epoch 49
# [-] Train_loss is 0.0060983405914157626 iteration is 30 on epoch 49
# [-] Train_loss is 0.005427189311012626 iteration is 40 on epoch 49
# [-] Train_loss is 0.005755245080217719 iteration is 10 on epoch 50
# [-] Train_loss is 0.006292945751920342 iteration is 20 on epoch 50
# [-] Train_loss is 0.006252885982394219 iteration is 30 on epoch 50
# [-] Train_loss is 0.005776265356689692 iteration is 40 on epoch 50
# [-] Train_loss is 0.005475004808977247 iteration is 10 on epoch 51
# [-] Train_loss is 0.005623903125524521 iteration is 20 on epoch 51
# [-] Train_loss is 0.00550417248159647 iteration is 30 on epoch 51
# [-] Train_loss is 0.005795206828042865 iteration is 40 on epoch 51
# [-] Train_loss is 0.005501844454556704 iteration is 10 on epoch 52
# [-] Train_loss is 0.00565896206535399 iteration is 20 on epoch 52
# [-] Train_loss is 0.005867105023935437 iteration is 30 on epoch 52
# [-] Train_loss is 0.005819362541660667 iteration is 40 on epoch 52
# [-] Train_loss is 0.005493129231035709 iteration is 10 on epoch 53
# [-] Train_loss is 0.005767494067549705 iteration is 20 on epoch 53
# [-] Train_loss is 0.005944153014570475 iteration is 30 on epoch 53
# [-] Train_loss is 0.0054030769504606726 iteration is 40 on epoch 53
# [-] Train_loss is 0.005553000001236796 iteration is 10 on epoch 54
# [-] Train_loss is 0.005256290081888437 iteration is 20 on epoch 54
# [-] Train_loss is 0.0052985872607678175 iteration is 30 on epoch 54
# [-] Train_loss is 0.00545713824685663 iteration is 40 on epoch 54
# [-] Train_loss is 0.005220507131889462 iteration is 10 on epoch 55
# [-] Train_loss is 0.00571983396075666 iteration is 20 on epoch 55
# [-] Train_loss is 0.005324648739770055 iteration is 30 on epoch 55
# [-] Train_loss is 0.005333554907701909 iteration is 40 on epoch 55
# [-] Train_loss is 0.005458717467263341 iteration is 10 on epoch 56
# [-] Train_loss is 0.005621718103066086 iteration is 20 on epoch 56
# [-] Train_loss is 0.005135094840079546 iteration is 30 on epoch 56
# [-] Train_loss is 0.004848280875012279 iteration is 40 on epoch 56
# [-] Train_loss is 0.005099446978420019 iteration is 10 on epoch 57
# [-] Train_loss is 0.004727630503475666 iteration is 20 on epoch 57
# [-] Train_loss is 0.005138397216796875 iteration is 30 on epoch 57
# [-] Train_loss is 0.0055725329089909795 iteration is 40 on epoch 57
# [-] Train_loss is 0.005617137486115098 iteration is 10 on epoch 58
# [-] Train_loss is 0.005362794362008571 iteration is 20 on epoch 58
# [-] Train_loss is 0.005370976915583014 iteration is 30 on epoch 58
# [-] Train_loss is 0.005239507369697094 iteration is 40 on epoch 58
# [-] Train_loss is 0.005031083663925529 iteration is 10 on epoch 59
# [-] Train_loss is 0.0051175776403397325 iteration is 20 on epoch 59
# [-] Train_loss is 0.005246185651049018 iteration is 30 on epoch 59
# [-] Train_loss is 0.0047054252121597525 iteration is 40 on epoch 59
# [-] Train_loss is 0.004841792257502675 iteration is 10 on epoch 60
# [-] Train_loss is 0.0048197758151218295 iteration is 20 on epoch 60
# [-] Train_loss is 0.004947194317355752 iteration is 30 on epoch 60
# [-] Train_loss is 0.0047509738244116305 iteration is 40 on epoch 60
# [-] Train_loss is 0.00460009875241667 iteration is 10 on epoch 61
# [-] Train_loss is 0.004547485988587141 iteration is 20 on epoch 61
# [-] Train_loss is 0.004818554455414415 iteration is 30 on epoch 61
# [-] Train_loss is 0.005172652145847678 iteration is 40 on epoch 61
# [-] Train_loss is 0.004939176887273788 iteration is 10 on epoch 62
# [-] Train_loss is 0.004808380780741572 iteration is 20 on epoch 62
# [-] Train_loss is 0.004810803988948465 iteration is 30 on epoch 62
# [-] Train_loss is 0.004653687542304397 iteration is 40 on epoch 62
# [-] Train_loss is 0.004467401024885476 iteration is 10 on epoch 63
# [-] Train_loss is 0.004705097083933652 iteration is 20 on epoch 63
# [-] Train_loss is 0.0047538514947518705 iteration is 30 on epoch 63
# [-] Train_loss is 0.004678455297835171 iteration is 40 on epoch 63
# [-] Train_loss is 0.004887933284044266 iteration is 10 on epoch 64
# [-] Train_loss is 0.00506102298386395 iteration is 20 on epoch 64
# [-] Train_loss is 0.004622970917262137 iteration is 30 on epoch 64
# [-] Train_loss is 0.004917470179498196 iteration is 40 on epoch 64
# [-] Train_loss is 0.0047342789126560095 iteration is 10 on epoch 65
# [-] Train_loss is 0.0051471048034727575 iteration is 20 on epoch 65
# [-] Train_loss is 0.004257504944689572 iteration is 30 on epoch 65
# [-] Train_loss is 0.004522697068750858 iteration is 40 on epoch 65
# [-] Train_loss is 0.004940428864210844 iteration is 10 on epoch 66
# [-] Train_loss is 0.004573973966762424 iteration is 20 on epoch 66
# [-] Train_loss is 0.004403334576636553 iteration is 30 on epoch 66
# [-] Train_loss is 0.0042549350531771776 iteration is 40 on epoch 66
# [-] Train_loss is 0.004530043341219425 iteration is 10 on epoch 67
# [-] Train_loss is 0.004326109774410725 iteration is 20 on epoch 67
# [-] Train_loss is 0.004813289036974311 iteration is 30 on epoch 67
# [-] Train_loss is 0.004457252891734242 iteration is 40 on epoch 67
# [-] Train_loss is 0.004262514389120042 iteration is 10 on epoch 68
# [-] Train_loss is 0.00408135058823973 iteration is 20 on epoch 68
# [-] Train_loss is 0.00463382126763463 iteration is 30 on epoch 68
# [-] Train_loss is 0.004128107405267656 iteration is 40 on epoch 68
# [-] Train_loss is 0.004328509466722608 iteration is 10 on epoch 69
# [-] Train_loss is 0.0045538050821051 iteration is 20 on epoch 69
# [-] Train_loss is 0.004488631407730282 iteration is 30 on epoch 69
# [-] Train_loss is 0.004410581896081567 iteration is 40 on epoch 69
# [-] Train_loss is 0.004262365214526653 iteration is 10 on epoch 70
# [-] Train_loss is 0.004306012555025518 iteration is 20 on epoch 70
# [-] Train_loss is 0.004411743814125657 iteration is 30 on epoch 70
# [-] Train_loss is 0.004309254582040012 iteration is 40 on epoch 70
# [-] Train_loss is 0.004313427163287998 iteration is 10 on epoch 71
# [-] Train_loss is 0.004347723769024014 iteration is 20 on epoch 71
# [-] Train_loss is 0.0041389500489458445 iteration is 30 on epoch 71
# [-] Train_loss is 0.0042090252507478 iteration is 40 on epoch 71
# [-] Train_loss is 0.003945964993909002 iteration is 10 on epoch 72
# [-] Train_loss is 0.003969502472318709 iteration is 20 on epoch 72
# [-] Train_loss is 0.004299078206531704 iteration is 30 on epoch 72
# [-] Train_loss is 0.004224765975959599 iteration is 40 on epoch 72
# [-] Train_loss is 0.004212820250540972 iteration is 10 on epoch 73
# [-] Train_loss is 0.004410884389653802 iteration is 20 on epoch 73
# [-] Train_loss is 0.004275136184878648 iteration is 30 on epoch 73
# [-] Train_loss is 0.004169693635776639 iteration is 40 on epoch 73
# [-] Train_loss is 0.00396108073182404 iteration is 10 on epoch 74
# [-] Train_loss is 0.0041302988771349195 iteration is 20 on epoch 74
# [-] Train_loss is 0.0038548428099602463 iteration is 30 on epoch 74
# [-] Train_loss is 0.004096786910668016 iteration is 40 on epoch 74
# [-] Train_loss is 0.004032171075232327 iteration is 10 on epoch 75
# [-] Train_loss is 0.004341688542626798 iteration is 20 on epoch 75
# [-] Train_loss is 0.004295010631904006 iteration is 30 on epoch 75
# [-] Train_loss is 0.004203002178110182 iteration is 40 on epoch 75
# [-] Train_loss is 0.0041729174321517345 iteration is 10 on epoch 76
# [-] Train_loss is 0.0038464704062789678 iteration is 20 on epoch 76
# [-] Train_loss is 0.003991138935089111 iteration is 30 on epoch 76
# [-] Train_loss is 0.0037024928722530605 iteration is 40 on epoch 76
# [-] Train_loss is 0.004239277821034193 iteration is 10 on epoch 77
# [-] Train_loss is 0.004102555429562926 iteration is 20 on epoch 77
# [-] Train_loss is 0.00414474627468735 iteration is 30 on epoch 77
# [-] Train_loss is 0.0038126159692183138 iteration is 40 on epoch 77
# [-] Train_loss is 0.004022209718823433 iteration is 10 on epoch 78
# [-] Train_loss is 0.0038258747663348913 iteration is 20 on epoch 78
# [-] Train_loss is 0.004196305549703539 iteration is 30 on epoch 78
# [-] Train_loss is 0.003574292059056461 iteration is 40 on epoch 78
# [-] Train_loss is 0.004063963633961975 iteration is 10 on epoch 79
# [-] Train_loss is 0.0040236252127215264 iteration is 20 on epoch 79
# [-] Train_loss is 0.004064564337022602 iteration is 30 on epoch 79
# [-] Train_loss is 0.003879418084397912 iteration is 40 on epoch 79
# [-] Train_loss is 0.003574048122391105 iteration is 10 on epoch 80
# [-] Train_loss is 0.003952075750567019 iteration is 20 on epoch 80
# [-] Train_loss is 0.003773659421131015 iteration is 30 on epoch 80
# [-] Train_loss is 0.003887808066792786 iteration is 40 on epoch 80
# [-] Train_loss is 0.0034348365385085343 iteration is 10 on epoch 81
# [-] Train_loss is 0.0036916170502081513 iteration is 20 on epoch 81
# [-] Train_loss is 0.0034170475788414477 iteration is 30 on epoch 81
# [-] Train_loss is 0.0040083502419292925 iteration is 40 on epoch 81
# [-] Train_loss is 0.0039051425410434604 iteration is 10 on epoch 82
# [-] Train_loss is 0.0037896803580224512 iteration is 20 on epoch 82
# [-] Train_loss is 0.0037460078718140723 iteration is 30 on epoch 82
# [-] Train_loss is 0.0038397379219532015 iteration is 40 on epoch 82
# [-] Train_loss is 0.00395743444096297 iteration is 10 on epoch 83
# [-] Train_loss is 0.0037753969663754106 iteration is 20 on epoch 83
# [-] Train_loss is 0.003862557583488524 iteration is 30 on epoch 83
# [-] Train_loss is 0.0038235247600823643 iteration is 40 on epoch 83
# [-] Train_loss is 0.003655447578057647 iteration is 10 on epoch 84
# [-] Train_loss is 0.0034887446789070966 iteration is 20 on epoch 84
# [-] Train_loss is 0.0035754945361986755 iteration is 30 on epoch 84
# [-] Train_loss is 0.003698495728895068 iteration is 40 on epoch 84
# [-] Train_loss is 0.0037005762569606304 iteration is 10 on epoch 85
# [-] Train_loss is 0.003497884701937437 iteration is 20 on epoch 85
# [-] Train_loss is 0.0035776129690930246 iteration is 30 on epoch 85
# [-] Train_loss is 0.0037203018553555013 iteration is 40 on epoch 85
# [-] Train_loss is 0.003888997039757669 iteration is 10 on epoch 86
# [-] Train_loss is 0.003853012854233384 iteration is 20 on epoch 86
# [-] Train_loss is 0.003353693918325007 iteration is 30 on epoch 86
# [-] Train_loss is 0.0035824599443003537 iteration is 40 on epoch 86
# [-] Train_loss is 0.0034257151884958146 iteration is 10 on epoch 87
# [-] Train_loss is 0.0033741491148248314 iteration is 20 on epoch 87
# [-] Train_loss is 0.003448550053872168 iteration is 30 on epoch 87
# [-] Train_loss is 0.003569405758753419 iteration is 40 on epoch 87
# [-] Train_loss is 0.0036955832503736017 iteration is 10 on epoch 88
# [-] Train_loss is 0.0035935784922912716 iteration is 20 on epoch 88
# [-] Train_loss is 0.003363151289522648 iteration is 30 on epoch 88
# [-] Train_loss is 0.0037921811919659374 iteration is 40 on epoch 88
# [-] Train_loss is 0.003456987254321575 iteration is 10 on epoch 89
# [-] Train_loss is 0.0036012812051922083 iteration is 20 on epoch 89
# [-] Train_loss is 0.003349044895730913 iteration is 30 on epoch 89
# [-] Train_loss is 0.0033312444342300297 iteration is 40 on epoch 89
# [-] Train_loss is 0.0033708757488057016 iteration is 10 on epoch 90
# [-] Train_loss is 0.0034978995798155667 iteration is 20 on epoch 90
# [-] Train_loss is 0.003145327349193394 iteration is 30 on epoch 90
# [-] Train_loss is 0.0033743427600711586 iteration is 40 on epoch 90
# [-] Train_loss is 0.003590236627496779 iteration is 10 on epoch 91
# [-] Train_loss is 0.0034974879352375867 iteration is 20 on epoch 91
# [-] Train_loss is 0.0035244754515588285 iteration is 30 on epoch 91
# [-] Train_loss is 0.003426533914171159 iteration is 40 on epoch 91
# [-] Train_loss is 0.003064501052722335 iteration is 10 on epoch 92
# [-] Train_loss is 0.003419153019785881 iteration is 20 on epoch 92
# [-] Train_loss is 0.0034523698734119533 iteration is 30 on epoch 92
# [-] Train_loss is 0.003366651316173375 iteration is 40 on epoch 92
# [-] Train_loss is 0.003278062865138054 iteration is 10 on epoch 93
# [-] Train_loss is 0.0035197703866288064 iteration is 20 on epoch 93
# [-] Train_loss is 0.00319272899068892 iteration is 30 on epoch 93
# [-] Train_loss is 0.0033703607739880683 iteration is 40 on epoch 93
# [-] Train_loss is 0.0033898244611918925 iteration is 10 on epoch 94
# [-] Train_loss is 0.0032269546296447515 iteration is 20 on epoch 94
# [-] Train_loss is 0.0034603041131049395 iteration is 30 on epoch 94
# [-] Train_loss is 0.0035527134081348778 iteration is 40 on epoch 94
# [-] Train_loss is 0.003069541044533253 iteration is 10 on epoch 95
# [-] Train_loss is 0.003155971714295447 iteration is 20 on epoch 95
# [-] Train_loss is 0.0030239564133808018 iteration is 30 on epoch 95
# [-] Train_loss is 0.0030423476826399566 iteration is 40 on epoch 95
# [-] Train_loss is 0.0031700615072622895 iteration is 10 on epoch 96
# [-] Train_loss is 0.0033532758709043263 iteration is 20 on epoch 96
# [-] Train_loss is 0.0030787711963057517 iteration is 30 on epoch 96
# [-] Train_loss is 0.0031882017385214565 iteration is 40 on epoch 96
# [-] Train_loss is 0.003055409761145711 iteration is 10 on epoch 97
# [-] Train_loss is 0.003310133027844131 iteration is 20 on epoch 97
# [-] Train_loss is 0.0032277713296934964 iteration is 30 on epoch 97
# [-] Train_loss is 0.003197802696377039 iteration is 40 on epoch 97
# [-] Train_loss is 0.0031228959560394287 iteration is 10 on epoch 98
# [-] Train_loss is 0.0033017623936757445 iteration is 20 on epoch 98
# [-] Train_loss is 0.0030703336698934434 iteration is 30 on epoch 98
# [-] Train_loss is 0.0030088205356150867 iteration is 40 on epoch 98
# [-] Train_loss is 0.0029751940397545694 iteration is 10 on epoch 99
# [-] Train_loss is 0.003307226113975048 iteration is 20 on epoch 99
# [-] Train_loss is 0.003179103531874716 iteration is 30 on epoch 99
# [-] Train_loss is 0.0029094642493873836 iteration is 40 on epoch 99

# %%
from sklearn.metrics import mean_squared_error
def get_mse_values(y_preds, y_true):
  mse_losses = []
  i = 0
  for pred in y_preds:
    mse_losses.append(mean_squared_error(y_true[i].tolist(),pred.tolist()))
    i += 1
  return torch.tensor(mse_losses)

def get_rmse_values(y_preds, y_true):
  mse_losses = []
  i = 0
  for pred in y_preds:
    mse_losses.append(mean_squared_error(y_true[i].tolist(),pred.tolist(), squared=False))
    i += 1
  return torch.tensor(mse_losses)

# %%
train_losses = []
i = 0
MSE_LOSSES = []
All_losses = []
RMSE_losses = []
for _ in range(100):
  batch, labels = get_batch(32, chunk="test")
  preds = Train_model(batch.to(device),None)
  optimizer.zero_grad()
  loss = criterion(preds, labels.to(device).float())
  train_losses.append(loss.item())
  preds_transposed = preds.transpose(1,0)
  labels_transposed = labels.transpose(1,0)
  All_losses.append(get_mse_values(preds_transposed, labels_transposed))
  RMSE_losses.append(get_rmse_values(preds_transposed, labels_transposed))
  MSE_LOSSES.append(torch.cosine_similarity(preds_transposed,labels_transposed.to(device)))
  i += 1
  if(i % 5 == 0):
    print(f"[-] Test_loss is {np.mean(train_losses)} iteration is {i}")
    train_losses = []
i = 0
# Out:
# [-] Test_loss is 0.026349030435085297 iteration is 5
# [-] Test_loss is 0.02676190733909607 iteration is 10
# [-] Test_loss is 0.02707536481320858 iteration is 15
# [-] Test_loss is 0.027162257209420206 iteration is 20
# [-] Test_loss is 0.02721026949584484 iteration is 25
# [-] Test_loss is 0.028533218055963518 iteration is 30
# [-] Test_loss is 0.02776256501674652 iteration is 35
# [-] Test_loss is 0.02851521261036396 iteration is 40
# [-] Test_loss is 0.02470049113035202 iteration is 45
# [-] Test_loss is 0.02714533545076847 iteration is 50
# [-] Test_loss is 0.026911637187004088 iteration is 55
# [-] Test_loss is 0.026012427732348443 iteration is 60
# [-] Test_loss is 0.024875691905617715 iteration is 65
# [-] Test_loss is 0.026519489660859107 iteration is 70
# [-] Test_loss is 0.026702719554305077 iteration is 75
# [-] Test_loss is 0.02792312279343605 iteration is 80
# [-] Test_loss is 0.029286670312285424 iteration is 85
# [-] Test_loss is 0.026029280945658685 iteration is 90
# [-] Test_loss is 0.027329669892787935 iteration is 95
# [-] Test_loss is 0.025773902982473375 iteration is 100

# %%
Cos_sim_stacked = torch.stack(MSE_LOSSES).mean(0)
i = 1
print(f"Class Class_Name Cosine Similarities \n")
for loss in Cos_sim_stacked.tolist():
  print(f"{i} {numeric_columns[i-1]} {loss}")
  i += 1
# Out:
# Class Class_Name Cosine Similarities
#
# 1 tempC 0.99999830620507
# 2 tempF 0.9999983528300209
# 3 windspeedMiles 0.9999973028752337
# 4 windspeedKmph 0.9999973803860366
# 5 winddirdegree 0.9989654623670391
# 6 weatherCode 0.9890496818758925
# 7 precipMM 0.9512377191299087
# 8 precipInches 0.6278441660323955
# 9 humidity 0.9995610102437027
# 10 visibilityKm 0.9999981824571457
# 11 visibilityMiles 0.9999944410787147
# 12 pressureMB 0.9998942068183291
# 13 pressureInches 0.7303429479572023
# 14 cloudcover 0.9964156442949534
# 15 HeatIndexC 0.9999973346543456
# 16 HeatIndexF 0.9999963908831012
# 17 DewPointC 0.9999960579940216
# 18 DewPointF 0.9999972759844427
# 19 WindChillC 0.9999945269498475
# 20 WindChillF 0.9999981307161293
# 21 WindGustMiles 0.9999947988724422
# 22 WindGustKmph 0.9999966781442085
# 23 FeelsLikeC 0.9999947464954673
# 24 FeelsLikeF 0.9999988360464751

# %%
from matplotlib import pyplot as plt
classes = [i for i in range(1,25)]
fig = plt.figure(figsize =(10, 5))
plt.title("Prediction vs Labels Cosine Similarities")
plt.bar(classes, Cos_sim_stacked.tolist())
plt.show()

# %%
All_losses_stacked = torch.stack(All_losses).mean(0)
from matplotlib import pyplot as plt
classes = [i for i in range(1,25)]
fig = plt.figure(figsize =(5, 3))
plt.title("Transformer Mean Squared Error")
plt.bar(classes, All_losses_stacked.tolist())
plt.show()

# %%
print(f"Class Class_Name Mean Squared Error \n")
i = 1
for loss in All_losses_stacked.tolist():
  print(f"{i} {numeric_columns[i-1]} {loss}")
  i += 1
# Out:
# Class Class_Name Mean Squared Error
#
# 1 tempC 9.37992394071112e-06
# 2 tempF 9.344654884591192e-06
# 3 windspeedMiles 1.1701965945318375e-05
# 4 windspeedKmph 7.058258178029991e-06
# 5 winddirdegree 0.0027729764563882214
# 6 weatherCode 0.01791993298200344
# 7 precipMM 0.06575141002981515
# 8 precipInches 0.2696102657407415
# 9 humidity 0.001052094305282936
# 10 visibilityKm 7.747847669040228e-06
# 11 visibilityMiles 2.0899573863934692e-05
# 12 pressureMB 0.00022090341374472343
# 13 pressureInches 0.28205750529448587
# 14 cloudcover 0.006700883429383009
# 15 HeatIndexC 1.0435432357817157e-05
# 16 HeatIndexF 1.3833790209463557e-05
# 17 DewPointC 1.7129663271317354e-05
# 18 DewPointF 8.537475076739614e-06
# 19 WindChillC 2.502584116420365e-05
# 20 WindChillF 8.16141719420288e-06
# 21 WindGustMiles 2.1702823214534145e-05
# 22 WindGustKmph 9.40817144260626e-06
# 23 FeelsLikeC 2.4473169779302685e-05
# 24 FeelsLikeF 5.495651199117935e-06

# %%
RMSE_losses_stacked = torch.stack(RMSE_losses).mean(0)
i = 1
print(f"Class RMSE Error \n")

for loss in RMSE_losses_stacked.tolist():
  print(f"{i} {loss}")
  i += 1
# Out:
# Class RMSE Error
#
# 1 0.0030160691959169993
# 2 0.0030140093429103522
# 3 0.003362652156864486
# 4 0.0024854677070516693
# 5 0.05147350039112192
# 6 0.13241898992703885
# 7 0.25249310031471917
# 8 0.5162936049681871
# 9 0.03206447832579608
# 10 0.00272997813373036
# 11 0.004424492605612204
# 12 0.014256887753650223
# 13 0.5291135812338863
# 14 0.08113864829760016
# 15 0.003133020014729721
# 16 0.003615096298200229
# 17 0.004038036507527475
# 18 0.0027747263898567033
# 19 0.004893521827157955
# 20 0.0027977102408221705
# 21 0.00456346079979781
# 22 0.0029354447015547936
# 23 0.004855249272766729
# 24 0.0023065018335289415

# %%
from matplotlib import pyplot as plt
classes = [i for i in range(1,25)]
fig = plt.figure(figsize =(5, 3))
plt.title("Transformer Root Mean Squared Error(RMSE)")
plt.bar(classes, RMSE_losses_stacked.tolist())
plt.show()

# %%
from torch import nn
class DetectorRNN(nn.Module):
    def __init__(self,no_layers,hidden_dim,embedding_dim,drop_prob=0.5):
        super(DetectorRNN,self).__init__()

        self.output_dim = output_dim
        self.hidden_dim = hidden_dim

        self.no_layers = no_layers
        # self.vocab_size = vocab_size

        # self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(input_size=embedding_dim,hidden_size=self.hidden_dim,
                           num_layers=no_layers, batch_first=True)


        # dropout layer
        self.dropout = nn.Dropout(0.3)

        # linear and sigmoid layer
        self.fc = nn.Linear(self.hidden_dim, output_dim)
        # self.sig = nn.Softmax(dim=)

    def forward(self,x,hidden):
        batch_size = x.size(0)

        lstm_out, hidden = self.lstm(x, hidden)

        out = self.dropout(lstm_out)
        sig_out = self.fc(out)


        sig_out = sig_out[:, -1] # get last batch of labels

        return sig_out, hidden

    def init_hidden(self, batch_size):
        h0 = torch.zeros((self.no_layers,batch_size,self.hidden_dim)).to(device)
        c0 = torch.zeros((self.no_layers,batch_size,self.hidden_dim)).to(device)
        hidden = (h0,c0)
        return hidden

# %%
no_layers = 1
embedding_dim = 64
output_dim = 24
hidden_dim = 200

# %%
Detector_model = DetectorRNN(1,hidden_dim,embedding_dim,drop_prob=0.1).to(device)

# %%
optimizer = torch.optim.Adam(Detector_model.parameters(),lr=1e-5)

# %%
epoch = 100
Detector_model.train()
Total_loss = 0
h = Detector_model.init_hidden(32)
clip = 5

for e in range(epoch):
  i = 0
  for _ in range(40):
    batch, labels = get_batch(32, chunk="train")
    h = tuple([each.data for each in h])
    Detector_model.zero_grad()
    preds,h = Detector_model(batch.to(device),h)
    loss = criterion(preds, labels.to(device).float())
    Total_loss += loss.item()
    loss.backward()
    nn.utils.clip_grad_norm_(Detector_model.parameters(), clip)
    optimizer.step()
    i += 1
    if(i % 20 == 0):
      print(f"[~] Epoch = {e+1} itteration = {i} Train_loss = {Total_loss/20}")
      Total_loss = 0
# Out:
# [~] Epoch = 1 itteration = 20 Train_loss = 0.9187224000692368
# [~] Epoch = 1 itteration = 40 Train_loss = 0.9041869133710861
# [~] Epoch = 2 itteration = 20 Train_loss = 0.885841828584671
# [~] Epoch = 2 itteration = 40 Train_loss = 0.8701476722955703
# [~] Epoch = 3 itteration = 20 Train_loss = 0.8522332936525345
# [~] Epoch = 3 itteration = 40 Train_loss = 0.8381471455097198
# [~] Epoch = 4 itteration = 20 Train_loss = 0.8167609333992004
# [~] Epoch = 4 itteration = 40 Train_loss = 0.79456447660923
# [~] Epoch = 5 itteration = 20 Train_loss = 0.7695645719766617
# [~] Epoch = 5 itteration = 40 Train_loss = 0.7425615787506104
# [~] Epoch = 6 itteration = 20 Train_loss = 0.7091916859149933
# [~] Epoch = 6 itteration = 40 Train_loss = 0.6714328408241272
# [~] Epoch = 7 itteration = 20 Train_loss = 0.6205265522003174
# [~] Epoch = 7 itteration = 40 Train_loss = 0.5506302744150162
# [~] Epoch = 8 itteration = 20 Train_loss = 0.4701750084757805
# [~] Epoch = 8 itteration = 40 Train_loss = 0.3705015853047371
# [~] Epoch = 9 itteration = 20 Train_loss = 0.25638203993439673
# [~] Epoch = 9 itteration = 40 Train_loss = 0.17885549813508989
# [~] Epoch = 10 itteration = 20 Train_loss = 0.13629790283739568
# [~] Epoch = 10 itteration = 40 Train_loss = 0.11315539665520191
# [~] Epoch = 11 itteration = 20 Train_loss = 0.0977223802357912
# [~] Epoch = 11 itteration = 40 Train_loss = 0.08556171953678131
# [~] Epoch = 12 itteration = 20 Train_loss = 0.07871809490025043
# [~] Epoch = 12 itteration = 40 Train_loss = 0.07121843807399272
# [~] Epoch = 13 itteration = 20 Train_loss = 0.06787260342389345
# [~] Epoch = 13 itteration = 40 Train_loss = 0.06413981635123492
# [~] Epoch = 14 itteration = 20 Train_loss = 0.06158692743629217
# [~] Epoch = 14 itteration = 40 Train_loss = 0.060780768282711506
# [~] Epoch = 15 itteration = 20 Train_loss = 0.05963672995567322
# [~] Epoch = 15 itteration = 40 Train_loss = 0.0584576727822423
# [~] Epoch = 16 itteration = 20 Train_loss = 0.05755567271262407
# [~] Epoch = 16 itteration = 40 Train_loss = 0.055628711730241774
# [~] Epoch = 17 itteration = 20 Train_loss = 0.05717542096972465
# [~] Epoch = 17 itteration = 40 Train_loss = 0.05534866712987423
# [~] Epoch = 18 itteration = 20 Train_loss = 0.054573364183306695
# [~] Epoch = 18 itteration = 40 Train_loss = 0.0539345296099782
# [~] Epoch = 19 itteration = 20 Train_loss = 0.05402620006352663
# [~] Epoch = 19 itteration = 40 Train_loss = 0.053854675590991975
# [~] Epoch = 20 itteration = 20 Train_loss = 0.05229855440557003
# [~] Epoch = 20 itteration = 40 Train_loss = 0.052566691488027575
# [~] Epoch = 21 itteration = 20 Train_loss = 0.05431752894073725
# [~] Epoch = 21 itteration = 40 Train_loss = 0.05437044184654951
# [~] Epoch = 22 itteration = 20 Train_loss = 0.05288462266325951
# [~] Epoch = 22 itteration = 40 Train_loss = 0.05228403899818659
# [~] Epoch = 23 itteration = 20 Train_loss = 0.05120504759252072
# [~] Epoch = 23 itteration = 40 Train_loss = 0.05143504086881876
# [~] Epoch = 24 itteration = 20 Train_loss = 0.05055184904485941
# [~] Epoch = 24 itteration = 40 Train_loss = 0.049710961245000365
# [~] Epoch = 25 itteration = 20 Train_loss = 0.0505581034347415
# [~] Epoch = 25 itteration = 40 Train_loss = 0.05165435932576656
# [~] Epoch = 26 itteration = 20 Train_loss = 0.049523083306849
# [~] Epoch = 26 itteration = 40 Train_loss = 0.04827285800129175
# [~] Epoch = 27 itteration = 20 Train_loss = 0.04936323910951614
# [~] Epoch = 27 itteration = 40 Train_loss = 0.0493991781026125
# [~] Epoch = 28 itteration = 20 Train_loss = 0.04920802637934685
# [~] Epoch = 28 itteration = 40 Train_loss = 0.05094928536564112
# [~] Epoch = 29 itteration = 20 Train_loss = 0.048989342711865905
# [~] Epoch = 29 itteration = 40 Train_loss = 0.04915316049009562
# [~] Epoch = 30 itteration = 20 Train_loss = 0.04770299196243286
# [~] Epoch = 30 itteration = 40 Train_loss = 0.04876906313002109
# [~] Epoch = 31 itteration = 20 Train_loss = 0.047762160561978816
# [~] Epoch = 31 itteration = 40 Train_loss = 0.04752842336893082
# [~] Epoch = 32 itteration = 20 Train_loss = 0.04754915572702885
# [~] Epoch = 32 itteration = 40 Train_loss = 0.047355661541223525
# [~] Epoch = 33 itteration = 20 Train_loss = 0.04666912741959095
# [~] Epoch = 33 itteration = 40 Train_loss = 0.047944344021379946
# [~] Epoch = 34 itteration = 20 Train_loss = 0.04757691118866205
# [~] Epoch = 34 itteration = 40 Train_loss = 0.04653783105313778
# [~] Epoch = 35 itteration = 20 Train_loss = 0.0448842940852046
# [~] Epoch = 35 itteration = 40 Train_loss = 0.04589943531900644
# [~] Epoch = 36 itteration = 20 Train_loss = 0.044552823156118394
# [~] Epoch = 36 itteration = 40 Train_loss = 0.04510877747088671
# [~] Epoch = 37 itteration = 20 Train_loss = 0.04625861551612616
# [~] Epoch = 37 itteration = 40 Train_loss = 0.04477301780134439
# [~] Epoch = 38 itteration = 20 Train_loss = 0.044650275632739066
# [~] Epoch = 38 itteration = 40 Train_loss = 0.046014373563230036
# [~] Epoch = 39 itteration = 20 Train_loss = 0.04379236157983542
# [~] Epoch = 39 itteration = 40 Train_loss = 0.044071005471050737
# [~] Epoch = 40 itteration = 20 Train_loss = 0.04388668145984411
# [~] Epoch = 40 itteration = 40 Train_loss = 0.04435167945921421
# [~] Epoch = 41 itteration = 20 Train_loss = 0.044103595055639745
# [~] Epoch = 41 itteration = 40 Train_loss = 0.043329978734254836
# [~] Epoch = 42 itteration = 20 Train_loss = 0.04483175054192543
# [~] Epoch = 42 itteration = 40 Train_loss = 0.04403599556535483
# [~] Epoch = 43 itteration = 20 Train_loss = 0.04221286792308092
# [~] Epoch = 43 itteration = 40 Train_loss = 0.04267004616558552
# [~] Epoch = 44 itteration = 20 Train_loss = 0.0423923522233963
# [~] Epoch = 44 itteration = 40 Train_loss = 0.04222151506692171
# [~] Epoch = 45 itteration = 20 Train_loss = 0.04248265940696001
# [~] Epoch = 45 itteration = 40 Train_loss = 0.04318051412701607
# [~] Epoch = 46 itteration = 20 Train_loss = 0.04385388288646937
# [~] Epoch = 46 itteration = 40 Train_loss = 0.04170396905392408
# [~] Epoch = 47 itteration = 20 Train_loss = 0.04121354352682829
# [~] Epoch = 47 itteration = 40 Train_loss = 0.041612574085593226
# [~] Epoch = 48 itteration = 20 Train_loss = 0.04095563478767872
# [~] Epoch = 48 itteration = 40 Train_loss = 0.04154115542769432
# [~] Epoch = 49 itteration = 20 Train_loss = 0.04082857798784971
# [~] Epoch = 49 itteration = 40 Train_loss = 0.0415727648884058
# [~] Epoch = 50 itteration = 20 Train_loss = 0.03995523676276207
# [~] Epoch = 50 itteration = 40 Train_loss = 0.040074830688536164
# [~] Epoch = 51 itteration = 20 Train_loss = 0.04125770814716816
# [~] Epoch = 51 itteration = 40 Train_loss = 0.03916705623269081
# [~] Epoch = 52 itteration = 20 Train_loss = 0.0396963607519865
# [~] Epoch = 52 itteration = 40 Train_loss = 0.03992726895958185
# [~] Epoch = 53 itteration = 20 Train_loss = 0.04050964247435331
# [~] Epoch = 53 itteration = 40 Train_loss = 0.03879564385861158
# [~] Epoch = 54 itteration = 20 Train_loss = 0.03932645320892334
# [~] Epoch = 54 itteration = 40 Train_loss = 0.03928179461508989
# [~] Epoch = 55 itteration = 20 Train_loss = 0.03873453997075558
# [~] Epoch = 55 itteration = 40 Train_loss = 0.0387195523828268
# [~] Epoch = 56 itteration = 20 Train_loss = 0.03924883306026459
# [~] Epoch = 56 itteration = 40 Train_loss = 0.03838775455951691
# [~] Epoch = 57 itteration = 20 Train_loss = 0.038686238788068296
# [~] Epoch = 57 itteration = 40 Train_loss = 0.03759363107383251
# [~] Epoch = 58 itteration = 20 Train_loss = 0.03859652355313301
# [~] Epoch = 58 itteration = 40 Train_loss = 0.037853117659688
# [~] Epoch = 59 itteration = 20 Train_loss = 0.037625535018742086
# [~] Epoch = 59 itteration = 40 Train_loss = 0.03822006471455097
# [~] Epoch = 60 itteration = 20 Train_loss = 0.03780027218163014
# [~] Epoch = 60 itteration = 40 Train_loss = 0.03806101884692907
# [~] Epoch = 61 itteration = 20 Train_loss = 0.037389842607080934
# [~] Epoch = 61 itteration = 40 Train_loss = 0.03752382630482316
# [~] Epoch = 62 itteration = 20 Train_loss = 0.03777242116630077
# [~] Epoch = 62 itteration = 40 Train_loss = 0.03719534799456596
# [~] Epoch = 63 itteration = 20 Train_loss = 0.03698713025078178
# [~] Epoch = 63 itteration = 40 Train_loss = 0.03636822868138552
# [~] Epoch = 64 itteration = 20 Train_loss = 0.03697563456371426
# [~] Epoch = 64 itteration = 40 Train_loss = 0.03631773302331567
# [~] Epoch = 65 itteration = 20 Train_loss = 0.03580298749729991
# [~] Epoch = 65 itteration = 40 Train_loss = 0.0355664337053895
# [~] Epoch = 66 itteration = 20 Train_loss = 0.03603752357885241
# [~] Epoch = 66 itteration = 40 Train_loss = 0.03610514560714364
# [~] Epoch = 67 itteration = 20 Train_loss = 0.035789309069514275
# [~] Epoch = 67 itteration = 40 Train_loss = 0.0355612875893712
# [~] Epoch = 68 itteration = 20 Train_loss = 0.03470822591334581
# [~] Epoch = 68 itteration = 40 Train_loss = 0.035708952229470015
# [~] Epoch = 69 itteration = 20 Train_loss = 0.03476280961185694
# [~] Epoch = 69 itteration = 40 Train_loss = 0.03452792596071959
# [~] Epoch = 70 itteration = 20 Train_loss = 0.034921161737293004
# [~] Epoch = 70 itteration = 40 Train_loss = 0.0345799645408988
# [~] Epoch = 71 itteration = 20 Train_loss = 0.034176974836736915
# [~] Epoch = 71 itteration = 40 Train_loss = 0.034661769215017554
# [~] Epoch = 72 itteration = 20 Train_loss = 0.0353409125469625
# [~] Epoch = 72 itteration = 40 Train_loss = 0.03461952712386847
# [~] Epoch = 73 itteration = 20 Train_loss = 0.03408427471294999
# [~] Epoch = 73 itteration = 40 Train_loss = 0.03321173219010234
# [~] Epoch = 74 itteration = 20 Train_loss = 0.034587707836180925
# [~] Epoch = 74 itteration = 40 Train_loss = 0.033530753944069146
# [~] Epoch = 75 itteration = 20 Train_loss = 0.0327132529579103
# [~] Epoch = 75 itteration = 40 Train_loss = 0.03234430328011513
# [~] Epoch = 76 itteration = 20 Train_loss = 0.03419506112113595
# [~] Epoch = 76 itteration = 40 Train_loss = 0.034280314855277536
# [~] Epoch = 77 itteration = 20 Train_loss = 0.032838393654674294
# [~] Epoch = 77 itteration = 40 Train_loss = 0.03279773779213428
# [~] Epoch = 78 itteration = 20 Train_loss = 0.0326310588978231
# [~] Epoch = 78 itteration = 40 Train_loss = 0.031762207951396705
# [~] Epoch = 79 itteration = 20 Train_loss = 0.03156648371368646
# [~] Epoch = 79 itteration = 40 Train_loss = 0.0323047767393291
# [~] Epoch = 80 itteration = 20 Train_loss = 0.03146753329783678
# [~] Epoch = 80 itteration = 40 Train_loss = 0.031843784544616935
# [~] Epoch = 81 itteration = 20 Train_loss = 0.03110879808664322
# [~] Epoch = 81 itteration = 40 Train_loss = 0.032664235960692165
# [~] Epoch = 82 itteration = 20 Train_loss = 0.03187707671895623
# [~] Epoch = 82 itteration = 40 Train_loss = 0.030972790904343128
# [~] Epoch = 83 itteration = 20 Train_loss = 0.03120511258020997
# [~] Epoch = 83 itteration = 40 Train_loss = 0.0313781744800508
# [~] Epoch = 84 itteration = 20 Train_loss = 0.03145499853417277
# [~] Epoch = 84 itteration = 40 Train_loss = 0.03134740032255649
# [~] Epoch = 85 itteration = 20 Train_loss = 0.030780392047017813
# [~] Epoch = 85 itteration = 40 Train_loss = 0.03188400212675333
# [~] Epoch = 86 itteration = 20 Train_loss = 0.03155754571780563
# [~] Epoch = 86 itteration = 40 Train_loss = 0.031478151492774484
# [~] Epoch = 87 itteration = 20 Train_loss = 0.03065417967736721
# [~] Epoch = 87 itteration = 40 Train_loss = 0.030778897739946843
# [~] Epoch = 88 itteration = 20 Train_loss = 0.0304734674282372
# [~] Epoch = 88 itteration = 40 Train_loss = 0.030014661699533464
# [~] Epoch = 89 itteration = 20 Train_loss = 0.029888993687927724
# [~] Epoch = 89 itteration = 40 Train_loss = 0.02947117043659091
# [~] Epoch = 90 itteration = 20 Train_loss = 0.030003226641565562
# [~] Epoch = 90 itteration = 40 Train_loss = 0.02973880534991622
# [~] Epoch = 91 itteration = 20 Train_loss = 0.030102705489844082
# [~] Epoch = 91 itteration = 40 Train_loss = 0.02941011665388942
# [~] Epoch = 92 itteration = 20 Train_loss = 0.029312850162386894
# [~] Epoch = 92 itteration = 40 Train_loss = 0.029759982787072658
# [~] Epoch = 93 itteration = 20 Train_loss = 0.02948742136359215
# [~] Epoch = 93 itteration = 40 Train_loss = 0.028372221160680056
# [~] Epoch = 94 itteration = 20 Train_loss = 0.02959210006520152
# [~] Epoch = 94 itteration = 40 Train_loss = 0.029220503102988005
# [~] Epoch = 95 itteration = 20 Train_loss = 0.028717100154608488
# [~] Epoch = 95 itteration = 40 Train_loss = 0.028341060131788255
# [~] Epoch = 96 itteration = 20 Train_loss = 0.028630953375250102
# [~] Epoch = 96 itteration = 40 Train_loss = 0.028267355263233186
# [~] Epoch = 97 itteration = 20 Train_loss = 0.028801843430846928
# [~] Epoch = 97 itteration = 40 Train_loss = 0.027350409794598816
# [~] Epoch = 98 itteration = 20 Train_loss = 0.02852222789078951
# [~] Epoch = 98 itteration = 40 Train_loss = 0.02860515546053648
# [~] Epoch = 99 itteration = 20 Train_loss = 0.028946236800402404
# [~] Epoch = 99 itteration = 40 Train_loss = 0.028282777033746244
# [~] Epoch = 100 itteration = 20 Train_loss = 0.028124717622995378
# [~] Epoch = 100 itteration = 40 Train_loss = 0.0279768374748528

# %%
i = 0
Total_loss = 0
MSE_LOSSES = []
All_losses = []
RMSE_losses = []
for _ in range(100):
  batch, labels = get_batch(32, chunk="test")
  h = tuple([each.data for each in h])
  Detector_model.zero_grad()
  preds,h = Detector_model(batch.to(device),h)
  loss = criterion(preds, labels.to(device).float())
  Total_loss += loss.item()
  preds_transposed = preds.transpose(1,0)
  labels_transposed = labels.transpose(1,0)
  All_losses.append(get_mse_values(preds_transposed, labels_transposed))
  RMSE_losses.append(get_rmse_values(preds_transposed, labels_transposed))
  MSE_LOSSES.append(torch.cosine_similarity(preds_transposed,labels_transposed.to(device)))
  i += 1
  if(i % 20 == 0):
    print(f"[~] Epoch = {e+1} itteration = {i} Train_loss = {Total_loss/20}")
    Total_loss = 0
# Out:
# [~] Epoch = 100 itteration = 20 Train_loss = 0.04850173350423574
# [~] Epoch = 100 itteration = 40 Train_loss = 0.04720296710729599
# [~] Epoch = 100 itteration = 60 Train_loss = 0.04795079957693815
# [~] Epoch = 100 itteration = 80 Train_loss = 0.04835578575730324
# [~] Epoch = 100 itteration = 100 Train_loss = 0.04707615748047829

# %%
Cos_sim_stacked = torch.stack(MSE_LOSSES).mean(0)
i = 1
print(f"Class Class_Name Cosine Similarities \n")
for loss in Cos_sim_stacked.tolist():
  print(f"{i} {numeric_columns[i-1]} {loss}")
  i += 1
# Out:
# Class Class_Name Cosine Similarities
#
# 1 tempC 0.9930970528664006
# 2 tempF 0.9934744476149391
# 3 windspeedMiles 0.9923094343402672
# 4 windspeedKmph 0.9924836263277546
# 5 winddirdegree 0.9900667794942015
# 6 weatherCode 0.9870156534869657
# 7 precipMM 0.9490014353596908
# 8 precipInches 0.47302062943685125
# 9 humidity 0.9911953380847266
# 10 visibilityKm 0.9934376040443765
# 11 visibilityMiles 0.9924380911104137
# 12 pressureMB 0.9929601673818131
# 13 pressureInches 0.6302296879825512
# 14 cloudcover 0.989963542259122
# 15 HeatIndexC 0.9927140278742735
# 16 HeatIndexF 0.9937682255347864
# 17 DewPointC 0.9933574118663814
# 18 DewPointF 0.9929726360796022
# 19 WindChillC 0.9927261905632797
# 20 WindChillF 0.9924200521876005
# 21 WindGustMiles 0.9917186855208692
# 22 WindGustKmph 0.9933592326361119
# 23 FeelsLikeC 0.9934142603884267
# 24 FeelsLikeF 0.9921514586231639

# %%
from matplotlib import pyplot as plt
classes = [i for i in range(1,25)]
fig = plt.figure(figsize =(10, 5))
plt.title("LSTM Predictions vs Labels Cosine Similarities")
plt.bar(classes, Cos_sim_stacked.tolist())
plt.show()

# %%
All_losses_stacked = torch.stack(All_losses).mean(0)
from matplotlib import pyplot as plt
classes = [i for i in range(1,25)]
fig = plt.figure(figsize =(5, 3))
plt.title("LSTM Mean Squared Error")
plt.bar(classes, All_losses_stacked.tolist())
plt.show()

# %%
print(f"Class Class_Name Mean Squared Error \n")
i = 1
for loss in All_losses_stacked.tolist():
  print(f"{i} {numeric_columns[i-1]} {loss}")
  i += 1
# Out:
# Class Class_Name Mean Squared Error
#
# 1 tempC 0.015090947140074978
# 2 tempF 0.014410815089925456
# 3 windspeedMiles 0.01580787539077152
# 4 windspeedKmph 0.015450388309573748
# 5 winddirdegree 0.020670339029554872
# 6 weatherCode 0.01995562857083195
# 7 precipMM 0.08526383535681938
# 8 precipInches 0.36163013026413876
# 9 humidity 0.017070942176332756
# 10 visibilityKm 0.013396058313748477
# 11 visibilityMiles 0.015532064538428062
# 12 pressureMB 0.01597568555950722
# 13 pressureInches 0.3659795112294134
# 14 cloudcover 0.0168004570732738
# 15 HeatIndexC 0.014993459033373563
# 16 HeatIndexF 0.016070565864319007
# 17 DewPointC 0.01377017795112951
# 18 DewPointF 0.015078584597648534
# 19 WindChillC 0.015265656944202777
# 20 WindChillF 0.01612769003001246
# 21 WindGustMiles 0.01698271561237658
# 22 WindGustKmph 0.014030249568026789
# 23 FeelsLikeC 0.015124182848464103
# 24 FeelsLikeF 0.017141749337568193

# %%
RMSE_losses_stacked = torch.stack(RMSE_losses).mean(0)
i = 1
print(f"Class RMSE Error \n")

for loss in RMSE_losses_stacked.tolist():
  print(f"{i} {loss}")
  i += 1
# Out:
# Class RMSE Error
#
# 1 0.1216119807309696
# 2 0.11921659641339026
# 3 0.12467884908120293
# 4 0.12346273918524918
# 5 0.14263473151183753
# 6 0.139956911568658
# 7 0.2900447959191503
# 8 0.5998618688223045
# 9 0.12959660924449995
# 10 0.11492338335722176
# 11 0.12357715805788916
# 12 0.1254678176481268
# 13 0.6032352136116466
# 14 0.12875649419178511
# 15 0.12161533457605554
# 16 0.12571783129463976
# 17 0.11627636435714632
# 18 0.1220060175365785
# 19 0.12261013557121139
# 20 0.12592195152986096
# 21 0.12946633980323127
# 22 0.11760320007756586
# 23 0.12223761773935013
# 24 0.1298879073357997

# %%
from matplotlib import pyplot as plt
classes = [i for i in range(1,25)]
fig = plt.figure(figsize =(5, 3))
plt.title("LSTM Root Mean Squared Error(RMSE)")
plt.bar(classes, RMSE_losses_stacked.tolist())
plt.show()
